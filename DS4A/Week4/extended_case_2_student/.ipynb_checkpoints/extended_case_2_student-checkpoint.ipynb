# %% [markdown]
# # The adverse health effects of air pollution - are we making any progress?
#
# <img src=files/air.jpg width="900">
#
# **Credit:**  [Flickr/E4C](https://www.flickr.com/people/44221799@N08/)

# %%
# Load relevant packages
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import statsmodels.formula.api as sm
import warnings

warnings.filterwarnings("ignore")  # Suppress all warnings

# %% [markdown]
# ## Introduction
#
# **Business Context.** Air pollution is a very serious issue that the global population is currently dealing with. The abundance of air pollutants is not only contributing to global warming, but it is also causing problematic health issues to the population. There have been numerous efforts to protect and improve air quality across most nations. However, it seems that we are making very little progress. One of the main causes of this is the fact that the majority of air pollutants are derived from the burning of fossil fuels such as *coal*. Big industries and several other economical and political factors have slowed the progress towards the use of renewable energy by promoting the use of fossil fuels. Nevertheless, if we educate the general population and create awareness of this issue, we will be able to overcome this problem in the future.
#
# For this case, you have been hired as a data science consultant for an important environmental organization. In order to promote awareness of environmental and greenhouse gas issues, your client is interested in a study of **plausible impacts of air contamination on the health of the global population**. They have gathered some *raw* data provided by the [World Health Organization](https://www.who.int/), [The Institute for Health Metrics and Evaluation](http://www.healthdata.org/) and the [World Bank Group](https://www.worldbank.org/). Your task is to conduct data analysis, search for potential information, and create visualizations that the client can use for their campaigns and grant applications.
#
# **Analytical Context.** You are given a folder, named ```files``` with *raw* data. This data contains quite a large number of variables and it is in a fairly disorganized state. In addition, one of the datasets contains very poor documentation, segmented into several datasets. Your objective will be to:
#
# 1. Extract and clean the relevant data. You will have to manipulate several datasets to obtain useful information for the case.
# 2. Conduct Exploratory Data Analysis. You will have to create meaningful plots, formulate meaningful hypotheses and study the relationship between various indicators related to air pollution.
#
# Additionally, the client has some broad questions they would like to answer:
# 1. Are we making any progress in reducing the amount of emitted pollutants across the globe?
# 2. Which are the critical regions where we should start environmental campaigns?
# 3. Are we making any progress in the prevention of deaths related to air pollution?
# 4. Which demographic characteristics seem to correlate with the number of health-related issues derived from air pollution?

# %% [markdown]
# ## Extracting and cleaning relevant data
#
# Let's take a look at the data provided by the client in the ```files``` folder. There, we see another folder  named ```WDI_csv``` with several CSV files corresponding to the World Bank's primary [World Development Indicators](https://datacatalog.worldbank.org/dataset/world-development-indicators). The client stated that this data may contain some useful information relevant to our study, but they have not told us anything aside from that. Thus, we are on our own in finding and extracting the relevant data for our study. This we will do next.
#
# Let's take a peek at the file ```WDIData.csv```:

# %%
WDI_data = pd.read_csv("./files/WDI_csv/WDIData.csv")
print(WDI_data.columns)
print(WDI_data.info())
print("# of countries: ", WDI_data["Country Code"].unique().shape[0])
WDI_data.head()
# Out:
# Index(['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code',
#        '1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
#        '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
#        '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
#        '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
#        '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
#        '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
#        '2014', '2015', '2016', '2017', '2018', '2019', 'Unnamed: 64'],
#       dtype='object')
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 377256 entries, 0 to 377255
# Data columns (total 65 columns):
#  #   Column          Non-Null Count   Dtype
# ---  ------          --------------   -----
#  0   Country Name    377256 non-null  object
#  1   Country Code    377256 non-null  object
#  2   Indicator Name  377256 non-null  object
#  3   Indicator Code  377256 non-null  object
#  4   1960            37395 non-null   float64
#  5   1961            41211 non-null   float64
#  6   1962            43413 non-null   float64
#  7   1963            43324 non-null   float64
#  8   1964            43861 non-null   float64
#  9   1965            46306 non-null   float64
#  10  1966            46087 non-null   float64
#  11  1967            47840 non-null   float64
#  12  1968            47422 non-null   float64
#  13  1969            49112 non-null   float64
#  14  1970            69736 non-null   float64
#  15  1971            76073 non-null   float64
#  16  1972            78854 non-null   float64
#  17  1973            78402 non-null   float64
#  18  1974            79804 non-null   float64
#  19  1975            83728 non-null   float64
#  20  1976            85833 non-null   float64
#  21  1977            89303 non-null   float64
#  22  1978            88911 non-null   float64
#  23  1979            89707 non-null   float64
#  24  1980            94479 non-null   float64
#  25  1981            96363 non-null   float64
#  26  1982            97575 non-null   float64
#  27  1983            97385 non-null   float64
#  28  1984            98228 non-null   float64
#  29  1985            99450 non-null   float64
#  30  1986            100294 non-null  float64
#  31  1987            101654 non-null  float64
#  32  1988            101307 non-null  float64
#  33  1989            103060 non-null  float64
#  34  1990            126117 non-null  float64
#  35  1991            131212 non-null  float64
#  36  1992            135229 non-null  float64
#  37  1993            136645 non-null  float64
#  38  1994            138646 non-null  float64
#  39  1995            146560 non-null  float64
#  40  1996            146450 non-null  float64
#  41  1997            147530 non-null  float64
#  42  1998            149527 non-null  float64
#  43  1999            154659 non-null  float64
#  44  2000            179600 non-null  float64
#  45  2001            169874 non-null  float64
#  46  2002            174693 non-null  float64
#  47  2003            175686 non-null  float64
#  48  2004            180936 non-null  float64
#  49  2005            194452 non-null  float64
#  50  2006            192699 non-null  float64
#  51  2007            196798 non-null  float64
#  52  2008            195843 non-null  float64
#  53  2009            196888 non-null  float64
#  54  2010            211863 non-null  float64
#  55  2011            203080 non-null  float64
#  56  2012            204810 non-null  float64
#  57  2013            200522 non-null  float64
#  58  2014            206201 non-null  float64
#  59  2015            201043 non-null  float64
#  60  2016            197174 non-null  float64
#  61  2017            176112 non-null  float64
#  62  2018            126115 non-null  float64
#  63  2019            21481 non-null   float64
#  64  Unnamed: 64     0 non-null       float64
# dtypes: float64(61), object(4)
# memory usage: 187.1+ MB
# None
# # of countries:  264
#   Country Name Country Code  \
# 0   Arab World          ARB
# 1   Arab World          ARB
# 2   Arab World          ARB
# 3   Arab World          ARB
# 4   Arab World          ARB
#
#                                       Indicator Name     Indicator Code  1960  \
# 0  2005 PPP conversion factor, GDP (LCU per inter...      PA.NUS.PPP.05   NaN
# 1  2005 PPP conversion factor, private consumptio...  PA.NUS.PRVT.PP.05   NaN
# 2  Access to clean fuels and technologies for coo...     EG.CFT.ACCS.ZS   NaN
# 3            Access to electricity (% of population)     EG.ELC.ACCS.ZS   NaN
# 4  Access to electricity, rural (% of rural popul...  EG.ELC.ACCS.RU.ZS   NaN
#
#    1961  1962  1963  1964  1965  ...       2011       2012       2013  \
# 0   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 1   NaN   NaN   NaN   NaN   NaN  ...        NaN        NaN        NaN
# 2   NaN   NaN   NaN   NaN   NaN  ...  82.783289  83.120303  83.533457
# 3   NaN   NaN   NaN   NaN   NaN  ...  86.428272  87.070576  88.176836
# 4   NaN   NaN   NaN   NaN   NaN  ...  73.942103  75.244104  77.162305
#
#         2014       2015       2016       2017  2018  2019  Unnamed: 64
# 0        NaN        NaN        NaN        NaN   NaN   NaN          NaN
# 1        NaN        NaN        NaN        NaN   NaN   NaN          NaN
# 2  83.897596  84.171599  84.510171        NaN   NaN   NaN          NaN
# 3  87.342739  89.130121  89.678685  90.273687   NaN   NaN          NaN
# 4  75.538976  78.741152  79.665635  80.749293   NaN   NaN          NaN
#
# [5 rows x 65 columns]

# %% [markdown]
# The data seems to have a large number of indicators dating from 1960. There are also columns containing country names and codes. Notice that the first couple of rows say ```Arab World```, which may indicate that the data contains broad regional data as well. We notice also that there are at least 100,000 entries with ```NaN``` values for each year column.
#
# Since we are interested in environmental indicators, we must get rid of any rows not relevant to our study. However, the number of indicators seems to be quite large and a manual inspection seems impossible. Let's load the file ```WDISeries.csv``` which seems to contain more information about the indicators:

# %%
WDI_ids = pd.read_csv("./files/WDI_csv/WDISeries.csv")
print(WDI_ids.columns)
WDI_ids.head()
# Out:
# Index(['Series Code', 'Topic', 'Indicator Name', 'Short definition',
#        'Long definition', 'Unit of measure', 'Periodicity', 'Base Period',
#        'Other notes', 'Aggregation method', 'Limitations and exceptions',
#        'Notes from original source', 'General comments', 'Source',
#        'Statistical concept and methodology', 'Development relevance',
#        'Related source links', 'Other web links', 'Related indicators',
#        'License Type', 'Unnamed: 20'],
#       dtype='object')
#          Series Code                                 Topic  \
# 0     AG.AGR.TRAC.NO  Environment: Agricultural production
# 1  AG.CON.FERT.PT.ZS  Environment: Agricultural production
# 2     AG.CON.FERT.ZS  Environment: Agricultural production
# 3     AG.LND.AGRI.K2                 Environment: Land use
# 4     AG.LND.AGRI.ZS                 Environment: Land use
#
#                                       Indicator Name Short definition  \
# 0                   Agricultural machinery, tractors              NaN
# 1  Fertilizer consumption (% of fertilizer produc...              NaN
# 2  Fertilizer consumption (kilograms per hectare ...              NaN
# 3                         Agricultural land (sq. km)              NaN
# 4                 Agricultural land (% of land area)              NaN
#
#                                      Long definition Unit of measure  \
# 0  Agricultural machinery refers to the number of...             NaN
# 1  Fertilizer consumption measures the quantity o...             NaN
# 2  Fertilizer consumption measures the quantity o...             NaN
# 3  Agricultural land refers to the share of land ...             NaN
# 4  Agricultural land refers to the share of land ...             NaN
#
#   Periodicity Base Period Other notes Aggregation method  ...  \
# 0      Annual         NaN         NaN                Sum  ...
# 1      Annual         NaN         NaN   Weighted average  ...
# 2      Annual         NaN         NaN   Weighted average  ...
# 3      Annual         NaN         NaN                Sum  ...
# 4      Annual         NaN         NaN   Weighted average  ...
#
#   Notes from original source General comments  \
# 0                        NaN              NaN
# 1                        NaN              NaN
# 2                        NaN              NaN
# 3                        NaN              NaN
# 4                        NaN              NaN
#
#                                               Source  \
# 0  Food and Agriculture Organization, electronic ...
# 1  Food and Agriculture Organization, electronic ...
# 2  Food and Agriculture Organization, electronic ...
# 3  Food and Agriculture Organization, electronic ...
# 4  Food and Agriculture Organization, electronic ...
#
#                  Statistical concept and methodology  \
# 0  A tractor provides the power and traction to m...
# 1  Fertilizer consumption measures the quantity o...
# 2  Fertilizer consumption measures the quantity o...
# 3  Agricultural land constitutes only a part of a...
# 4  Agriculture is still a major sector in many ec...
#
#                                Development relevance Related source links  \
# 0  Agricultural land covers more than one-third o...                  NaN
# 1  Factors such as the green revolution, has led ...                  NaN
# 2  Factors such as the green revolution, has led ...                  NaN
# 3  Agricultural land covers more than one-third o...                  NaN
# 4  Agricultural land covers more than one-third o...                  NaN
#
#   Other web links  Related indicators License Type Unnamed: 20
# 0             NaN                 NaN    CC BY-4.0         NaN
# 1             NaN                 NaN    CC BY-4.0         NaN
# 2             NaN                 NaN    CC BY-4.0         NaN
# 3             NaN                 NaN    CC BY-4.0         NaN
# 4             NaN                 NaN    CC BY-4.0         NaN
#
# [5 rows x 21 columns]

# %% [markdown]
# Bingo! The ```WDI_ids``` DataFrame contains a column named ```Topic```. Moreover, it seems that *Environment* is listed as a key topic in the column.

# %% [markdown]
# ### Exercise 1:
#
# Extract all the rows that have the topic key *Environment* in ```WDI_ids```. Add to the resulting DataFrame a new column named ```Subtopic``` which contains the corresponding subtopic of the indicator. For example, the subtopic of ```Environment: Agricultural production``` is ```Agricultural production```. Which subtopics do you think are of interest to us?
#
# **Hint:** Remember that you can apply string methods to Series using the ```str()``` method of ```pandas```.

# %% [markdown]
# **Answer.**
#
# Subtopics of interest could be:
#
# - Energy production & use
# - Emissions
# - Biodiversity & protected areas
# - Density & urbanization

# %%
environmentDf = WDI_ids[WDI_ids["Topic"].str.startswith("Environment")].copy()
environmentDf
# Out:
#             Series Code                                 Topic  \
# 0        AG.AGR.TRAC.NO  Environment: Agricultural production
# 1     AG.CON.FERT.PT.ZS  Environment: Agricultural production
# 2        AG.CON.FERT.ZS  Environment: Agricultural production
# 3        AG.LND.AGRI.K2                 Environment: Land use
# 4        AG.LND.AGRI.ZS                 Environment: Land use
# ...                 ...                                   ...
# 1322     SP.RUR.TOTL.ZG   Environment: Density & urbanization
# 1323     SP.RUR.TOTL.ZS   Environment: Density & urbanization
# 1324        SP.URB.GROW   Environment: Density & urbanization
# 1325        SP.URB.TOTL   Environment: Density & urbanization
# 1326  SP.URB.TOTL.IN.ZS   Environment: Density & urbanization
#
#                                          Indicator Name Short definition  \
# 0                      Agricultural machinery, tractors              NaN
# 1     Fertilizer consumption (% of fertilizer produc...              NaN
# 2     Fertilizer consumption (kilograms per hectare ...              NaN
# 3                            Agricultural land (sq. km)              NaN
# 4                    Agricultural land (% of land area)              NaN
# ...                                                 ...              ...
# 1322                 Rural population growth (annual %)              NaN
# 1323           Rural population (% of total population)              NaN
# 1324                 Urban population growth (annual %)              NaN
# 1325                                   Urban population              NaN
# 1326           Urban population (% of total population)              NaN
#
#                                         Long definition Unit of measure  \
# 0     Agricultural machinery refers to the number of...             NaN
# 1     Fertilizer consumption measures the quantity o...             NaN
# 2     Fertilizer consumption measures the quantity o...             NaN
# 3     Agricultural land refers to the share of land ...             NaN
# 4     Agricultural land refers to the share of land ...             NaN
# ...                                                 ...             ...
# 1322  Rural population refers to people living in ru...             NaN
# 1323  Rural population refers to people living in ru...             NaN
# 1324  Urban population refers to people living in ur...             NaN
# 1325  Urban population refers to people living in ur...             NaN
# 1326  Urban population refers to people living in ur...             NaN
#
#      Periodicity Base Period Other notes Aggregation method  ...  \
# 0         Annual         NaN         NaN                Sum  ...
# 1         Annual         NaN         NaN   Weighted average  ...
# 2         Annual         NaN         NaN   Weighted average  ...
# 3         Annual         NaN         NaN                Sum  ...
# 4         Annual         NaN         NaN   Weighted average  ...
# ...          ...         ...         ...                ...  ...
# 1322      Annual         NaN         NaN   Weighted average  ...
# 1323      Annual         NaN         NaN   Weighted average  ...
# 1324      Annual         NaN         NaN   Weighted average  ...
# 1325      Annual         NaN         NaN                Sum  ...
# 1326      Annual         NaN         NaN   Weighted average  ...
#
#      Notes from original source General comments  \
# 0                           NaN              NaN
# 1                           NaN              NaN
# 2                           NaN              NaN
# 3                           NaN              NaN
# 4                           NaN              NaN
# ...                         ...              ...
# 1322                        NaN              NaN
# 1323                        NaN              NaN
# 1324                        NaN              NaN
# 1325                        NaN              NaN
# 1326                        NaN              NaN
#
#                                                  Source  \
# 0     Food and Agriculture Organization, electronic ...
# 1     Food and Agriculture Organization, electronic ...
# 2     Food and Agriculture Organization, electronic ...
# 3     Food and Agriculture Organization, electronic ...
# 4     Food and Agriculture Organization, electronic ...
# ...                                                 ...
# 1322  World Bank staff estimates based on the United...
# 1323  World Bank staff estimates based on the United...
# 1324  World Bank staff estimates based on the United...
# 1325  World Bank staff estimates based on the United...
# 1326  United Nations Population Division. World Urba...
#
#                     Statistical concept and methodology  \
# 0     A tractor provides the power and traction to m...
# 1     Fertilizer consumption measures the quantity o...
# 2     Fertilizer consumption measures the quantity o...
# 3     Agricultural land constitutes only a part of a...
# 4     Agriculture is still a major sector in many ec...
# ...                                                 ...
# 1322  Rural population is calculated as the differen...
# 1323  Rural population is calculated as the differen...
# 1324  Urban population refers to people living in ur...
# 1325  Urban population refers to people living in ur...
# 1326  Urban population refers to people living in ur...
#
#                                   Development relevance Related source links  \
# 0     Agricultural land covers more than one-third o...                  NaN
# 1     Factors such as the green revolution, has led ...                  NaN
# 2     Factors such as the green revolution, has led ...                  NaN
# 3     Agricultural land covers more than one-third o...                  NaN
# 4     Agricultural land covers more than one-third o...                  NaN
# ...                                                 ...                  ...
# 1322  The rural population is calculated using the u...                  NaN
# 1323  The rural population is calculated using the u...                  NaN
# 1324  Explosive growth of cities globally signifies ...                  NaN
# 1325  Explosive growth of cities globally signifies ...                  NaN
# 1326  Explosive growth of cities globally signifies ...                  NaN
#
#      Other web links  Related indicators License Type Unnamed: 20
# 0                NaN                 NaN    CC BY-4.0         NaN
# 1                NaN                 NaN    CC BY-4.0         NaN
# 2                NaN                 NaN    CC BY-4.0         NaN
# 3                NaN                 NaN    CC BY-4.0         NaN
# 4                NaN                 NaN    CC BY-4.0         NaN
# ...              ...                 ...          ...         ...
# 1322             NaN                 NaN    CC BY-4.0         NaN
# 1323             NaN                 NaN    CC BY-4.0         NaN
# 1324             NaN                 NaN    CC BY-4.0         NaN
# 1325             NaN                 NaN    CC BY-4.0         NaN
# 1326             NaN                 NaN    CC BY-4.0         NaN
#
# [138 rows x 21 columns]

# %%
environmentDf["Subtopic"] = environmentDf["Topic"].apply(lambda x: x[x.find(":")+2:])
environmentDf["Subtopic"].unique()
# Out:
# array(['Agricultural production', 'Land use', 'Energy production & use',
#        'Emissions', 'Biodiversity & protected areas',
#        'Density & urbanization', 'Freshwater',
#        'Natural resources contribution to GDP'], dtype=object)

# %% [markdown]
# -------

# %% [markdown]
# We may find several of these subtopics relevant to our study, but probably the most interesting for us now is the ```Emissions``` subtopic.

# %% [markdown]
# ### Exercise 2:
#
# Use the results of Exercise 1 to create a new DataFrame with the history of all emissions indicators for countries and major regions. Call this new DataFrame ```Emissions_df```. How many emissions indicators are in the study?

# %% [markdown]
# **Answer.**
#
# 42 indicators are being studied and all the countries have all the 42 indicators

# %%
# Emissions_df
columnsOfInterest = ["Series Code","Topic","Indicator Name","Short definition","Long definition"]
# print(*environmentDf.loc[environmentDf["Subtopic"] == "Emissions","Indicator Name"],sep="\n")
codesToGet = environmentDf.loc[environmentDf["Subtopic"] == "Emissions","Series Code"]
print("# of topics: ",codesToGet.shape)
codesToGet
# Out:
# # of topics:  (42,)
# 217       EN.ATM.CO2E.EG.ZS
# 218       EN.ATM.CO2E.GF.KT
# 219       EN.ATM.CO2E.GF.ZS
# 220       EN.ATM.CO2E.KD.GD
# 221          EN.ATM.CO2E.KT
# 222       EN.ATM.CO2E.LF.KT
# 223       EN.ATM.CO2E.LF.ZS
# 224          EN.ATM.CO2E.PC
# 225       EN.ATM.CO2E.PP.GD
# 226    EN.ATM.CO2E.PP.GD.KD
# 227       EN.ATM.CO2E.SF.KT
# 228       EN.ATM.CO2E.SF.ZS
# 229       EN.ATM.GHGO.KT.CE
# 230          EN.ATM.GHGO.ZG
# 231       EN.ATM.GHGT.KT.CE
# 232          EN.ATM.GHGT.ZG
# 233       EN.ATM.HFCG.KT.CE
# 234    EN.ATM.METH.AG.KT.CE
# 235       EN.ATM.METH.AG.ZS
# 236    EN.ATM.METH.EG.KT.CE
# 237       EN.ATM.METH.EG.ZS
# 238       EN.ATM.METH.KT.CE
# 239          EN.ATM.METH.ZG
# 240    EN.ATM.NOXE.AG.KT.CE
# 241       EN.ATM.NOXE.AG.ZS
# 242    EN.ATM.NOXE.EG.KT.CE
# 243       EN.ATM.NOXE.EG.ZS
# 244       EN.ATM.NOXE.KT.CE
# 245          EN.ATM.NOXE.ZG
# 246       EN.ATM.PFCG.KT.CE
# 247       EN.ATM.PM25.MC.M3
# 248    EN.ATM.PM25.MC.T1.ZS
# 249    EN.ATM.PM25.MC.T2.ZS
# 250    EN.ATM.PM25.MC.T3.ZS
# 251       EN.ATM.PM25.MC.ZS
# 252       EN.ATM.SF6G.KT.CE
# 255       EN.CLC.GHGR.MT.CE
# 257          EN.CO2.BLDG.ZS
# 258          EN.CO2.ETOT.ZS
# 259          EN.CO2.MANF.ZS
# 260          EN.CO2.OTHX.ZS
# 261          EN.CO2.TRAN.ZS
# Name: Series Code, dtype: object

# %%
Emissions_df = WDI_data[WDI_data["Indicator Code"].isin(codesToGet)].copy()
Emissions_df
# Out:
#        Country Name Country Code  \
# 64       Arab World          ARB
# 65       Arab World          ARB
# 66       Arab World          ARB
# 67       Arab World          ARB
# 191      Arab World          ARB
# ...             ...          ...
# 376814     Zimbabwe          ZWE
# 376815     Zimbabwe          ZWE
# 377064     Zimbabwe          ZWE
# 377160     Zimbabwe          ZWE
# 377161     Zimbabwe          ZWE
#
#                                            Indicator Name  \
# 64            Agricultural methane emissions (% of total)
# 65      Agricultural methane emissions (thousand metri...
# 66      Agricultural nitrous oxide emissions (% of total)
# 67      Agricultural nitrous oxide emissions (thousand...
# 191                CO2 emissions (kg per 2010 US$ of GDP)
# ...                                                   ...
# 376814  PM2.5 pollution, population exposed to levels ...
# 376815  PM2.5 pollution, population exposed to levels ...
# 377064  SF6 gas emissions (thousand metric tons of CO2...
# 377160  Total greenhouse gas emissions (% change from ...
# 377161  Total greenhouse gas emissions (kt of CO2 equi...
#
#               Indicator Code  1960  1961  1962  1963  1964  1965  ...  \
# 64         EN.ATM.METH.AG.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 65      EN.ATM.METH.AG.KT.CE   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 66         EN.ATM.NOXE.AG.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 67      EN.ATM.NOXE.AG.KT.CE   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 191        EN.ATM.CO2E.KD.GD   NaN   NaN   NaN   NaN   NaN   NaN  ...
# ...                      ...   ...   ...   ...   ...   ...   ...  ...
# 376814  EN.ATM.PM25.MC.T2.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 376815  EN.ATM.PM25.MC.T3.ZS   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 377064     EN.ATM.SF6G.KT.CE   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 377160        EN.ATM.GHGT.ZG   NaN   NaN   NaN   NaN   NaN   NaN  ...
# 377161     EN.ATM.GHGT.KT.CE   NaN   NaN   NaN   NaN   NaN   NaN  ...
#
#                 2011          2012        2013        2014        2015  \
# 64               NaN           NaN         NaN         NaN         NaN
# 65               NaN           NaN         NaN         NaN         NaN
# 66               NaN           NaN         NaN         NaN         NaN
# 67               NaN           NaN         NaN         NaN         NaN
# 191         0.757162      0.770413    0.737665    0.769023         NaN
# ...              ...           ...         ...         ...         ...
# 376814     16.430216     22.112287   16.486892   18.625311    7.219464
# 376815    100.000000    100.000000  100.000000  100.000000  100.000000
# 377064           NaN           NaN         NaN         NaN         NaN
# 377160    103.876779    105.289436         NaN         NaN         NaN
# 377161  71561.952250  72057.803322         NaN         NaN         NaN
#
#               2016       2017  2018  2019  Unnamed: 64
# 64             NaN        NaN   NaN   NaN          NaN
# 65             NaN        NaN   NaN   NaN          NaN
# 66             NaN        NaN   NaN   NaN          NaN
# 67             NaN        NaN   NaN   NaN          NaN
# 191            NaN        NaN   NaN   NaN          NaN
# ...            ...        ...   ...   ...          ...
# 376814    8.708582    8.06692   NaN   NaN          NaN
# 376815  100.000000  100.00000   NaN   NaN          NaN
# 377064         NaN        NaN   NaN   NaN          NaN
# 377160         NaN        NaN   NaN   NaN          NaN
# 377161         NaN        NaN   NaN   NaN          NaN
#
# [11088 rows x 65 columns]

# %%
print("# of countries: ", Emissions_df["Country Code"].unique().shape[0])
sum(Emissions_df.groupby(["Country Code"]).count()["Indicator Code"] < 42)
# Out:
# # of countries:  264
# 0

# %% [markdown]
# ### Exercise 3:
#
# The DataFrame ```Emissions_df``` has one column per year of observation. Data in this form is usually referred to as data in *wide format*, as the number of columns is high. However, it might be easier to query and filter the data if we had a single column containing the year in which each indicator was calculated. This way, *each observation will be represented by a single row*. Use the ```pandas``` function [```melt()```](https://pandas.pydata.org/docs/reference/api/pandas.melt.html) to reshape the ```Emissions_df``` data into *long format*. The resulting DataFrame should contain a pair of new columns named ```Year``` and ```Indicator Value```:

# %% [markdown]
# **Answer.**

# %%
idVars = ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code']
valueVars = ['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', 'Unnamed: 64']


EmissionsMelt_df = Emissions_df.melt(idVars,valueVars,"year","Indicator Value").copy()
EmissionsMelt_df
# Out:
#        Country Name Country Code  \
# 0        Arab World          ARB
# 1        Arab World          ARB
# 2        Arab World          ARB
# 3        Arab World          ARB
# 4        Arab World          ARB
# ...             ...          ...
# 676363     Zimbabwe          ZWE
# 676364     Zimbabwe          ZWE
# 676365     Zimbabwe          ZWE
# 676366     Zimbabwe          ZWE
# 676367     Zimbabwe          ZWE
#
#                                            Indicator Name  \
# 0             Agricultural methane emissions (% of total)
# 1       Agricultural methane emissions (thousand metri...
# 2       Agricultural nitrous oxide emissions (% of total)
# 3       Agricultural nitrous oxide emissions (thousand...
# 4                  CO2 emissions (kg per 2010 US$ of GDP)
# ...                                                   ...
# 676363  PM2.5 pollution, population exposed to levels ...
# 676364  PM2.5 pollution, population exposed to levels ...
# 676365  SF6 gas emissions (thousand metric tons of CO2...
# 676366  Total greenhouse gas emissions (% change from ...
# 676367  Total greenhouse gas emissions (kt of CO2 equi...
#
#               Indicator Code         year  Indicator Value
# 0          EN.ATM.METH.AG.ZS         1960              NaN
# 1       EN.ATM.METH.AG.KT.CE         1960              NaN
# 2          EN.ATM.NOXE.AG.ZS         1960              NaN
# 3       EN.ATM.NOXE.AG.KT.CE         1960              NaN
# 4          EN.ATM.CO2E.KD.GD         1960              NaN
# ...                      ...          ...              ...
# 676363  EN.ATM.PM25.MC.T2.ZS  Unnamed: 64              NaN
# 676364  EN.ATM.PM25.MC.T3.ZS  Unnamed: 64              NaN
# 676365     EN.ATM.SF6G.KT.CE  Unnamed: 64              NaN
# 676366        EN.ATM.GHGT.ZG  Unnamed: 64              NaN
# 676367     EN.ATM.GHGT.KT.CE  Unnamed: 64              NaN
#
# [676368 rows x 6 columns]

# %% [markdown]
# -------

# %% [markdown]
# ### Exercise 4:
#
# The column ```Indicator Value``` of the new ```Emissions_df``` contains a bunch of ```NaN``` values. Additionally, the ```Year``` column contains an ```Unnamed: 64``` value. What procedure should we follow to clean these missing values in our DataFrame? Proceed with your suggested cleaning process.

# %% [markdown]
# **Answer.**
# Since indicator value for unnamed field always is Na then those values are skipped and when the indicator value is NaN then it entry cannot be properly analyzed, so those entries are skipped as well

# %%
isUnnamed = EmissionsMelt_df["year"] == "Unnamed: 64"
isNa = EmissionsMelt_df["Indicator Value"].isna()
print("# of rows: ",EmissionsMelt_df.shape[0])
print("# of NA's: ",EmissionsMelt_df[isNa].shape[0])
print("# of unnameds: ",EmissionsMelt_df[isUnnamed].shape[0])
print("# of unnamed non NA's: ",EmissionsMelt_df[isUnnamed & ~ isNa].shape[0])
print(EmissionsMelt_df[isUnnamed]["Indicator Value"].unique())

EmissionsMelt_df = EmissionsMelt_df[~isUnnamed].copy()

EmissionsMeltClean = EmissionsMelt_df.dropna()
EmissionsMeltClean
# Out:
# # of rows:  676368
# # of NA's:  350510
# # of unnameds:  11088
# # of unnamed non NA's:  0
# [nan]
#        Country Name Country Code  \
# 7        Arab World          ARB
# 8        Arab World          ARB
# 10       Arab World          ARB
# 12       Arab World          ARB
# 13       Arab World          ARB
# ...             ...          ...
# 643097     Zimbabwe          ZWE
# 643098     Zimbabwe          ZWE
# 643099     Zimbabwe          ZWE
# 643100     Zimbabwe          ZWE
# 652856        Sudan          SDN
#
#                                            Indicator Name  \
# 7                                      CO2 emissions (kt)
# 8                  CO2 emissions (metric tons per capita)
# 10      CO2 emissions from gaseous fuel consumption (%...
# 12      CO2 emissions from liquid fuel consumption (% ...
# 13        CO2 emissions from liquid fuel consumption (kt)
# ...                                                   ...
# 643097  PM2.5 air pollution, population exposed to lev...
# 643098  PM2.5 pollution, population exposed to levels ...
# 643099  PM2.5 pollution, population exposed to levels ...
# 643100  PM2.5 pollution, population exposed to levels ...
# 652856             CO2 emissions (metric tons per capita)
#
#               Indicator Code  year  Indicator Value
# 7             EN.ATM.CO2E.KT  1960     59535.396567
# 8             EN.ATM.CO2E.PC  1960         0.645736
# 10         EN.ATM.CO2E.GF.ZS  1960         5.041292
# 12         EN.ATM.CO2E.LF.ZS  1960        84.851473
# 13         EN.ATM.CO2E.LF.KT  1960     50539.802737
# ...                      ...   ...              ...
# 643097     EN.ATM.PM25.MC.ZS  2017       100.000000
# 643098  EN.ATM.PM25.MC.T1.ZS  2017         0.000000
# 643099  EN.ATM.PM25.MC.T2.ZS  2017         8.066920
# 643100  EN.ATM.PM25.MC.T3.ZS  2017       100.000000
# 652856        EN.ATM.CO2E.PC  2018         0.000000
#
# [325858 rows x 6 columns]

# %% [markdown]
# -------

# %% [markdown]
# ### Exercise 5:
#
# Split the ```Emissions_df``` into two DataFrames, one containing only countries and the other containing only regions. Name these ```Emissions_C_df``` and ```Emissions_R_df``` respectively.
#
# **Hint:** You may want to inspect the file ```WDICountry.csv``` for this task. Region country codes may be found by looking at ```null``` values of the ```Region``` column in ```WDICountry```.

# %% [markdown]
# **Answer.**

# %%
WDICountry = pd.read_csv("files/WDI_csv/WDICountry.csv")
WDICountry
# Out:
#     Country Code    Short Name    Table Name                     Long Name  \
# 0            ABW         Aruba         Aruba                         Aruba
# 1            AFG   Afghanistan   Afghanistan  Islamic State of Afghanistan
# 2            AGO        Angola        Angola   People's Republic of Angola
# 3            ALB       Albania       Albania           Republic of Albania
# 4            AND       Andorra       Andorra       Principality of Andorra
# ..           ...           ...           ...                           ...
# 258          XKX        Kosovo        Kosovo            Republic of Kosovo
# 259          YEM         Yemen   Yemen, Rep.             Republic of Yemen
# 260          ZAF  South Africa  South Africa      Republic of South Africa
# 261          ZMB        Zambia        Zambia            Republic of Zambia
# 262          ZWE      Zimbabwe      Zimbabwe          Republic of Zimbabwe
#
#     2-alpha code       Currency Unit  \
# 0             AW       Aruban florin
# 1             AF      Afghan afghani
# 2             AO      Angolan kwanza
# 3             AL        Albanian lek
# 4             AD                Euro
# ..           ...                 ...
# 258           XK                Euro
# 259           YE         Yemeni rial
# 260           ZA  South African rand
# 261           ZM  New Zambian kwacha
# 262           ZW         U.S. dollar
#
#                                          Special Notes  \
# 0                                                  NaN
# 1                                                  NaN
# 2                                                  NaN
# 3                                                  NaN
# 4                                                  NaN
# ..                                                 ...
# 258                                                NaN
# 259                                                NaN
# 260  Fiscal year end: March 31; reporting period fo...
# 261  National accounts data were rebased to reflect...
# 262                                                NaN
#
#                          Region         Income Group WB-2 code  ...  \
# 0     Latin America & Caribbean          High income        AW  ...
# 1                    South Asia           Low income        AF  ...
# 2            Sub-Saharan Africa  Lower middle income        AO  ...
# 3         Europe & Central Asia  Upper middle income        AL  ...
# 4         Europe & Central Asia          High income        AD  ...
# ..                          ...                  ...       ...  ...
# 258       Europe & Central Asia  Upper middle income        XK  ...
# 259  Middle East & North Africa           Low income        RY  ...
# 260          Sub-Saharan Africa  Upper middle income        ZA  ...
# 261          Sub-Saharan Africa  Lower middle income        ZM  ...
# 262          Sub-Saharan Africa  Lower middle income        ZW  ...
#
#        Government Accounting concept  \
# 0                                NaN
# 1    Consolidated central government
# 2       Budgetary central government
# 3    Consolidated central government
# 4                                NaN
# ..                               ...
# 258                              NaN
# 259                              NaN
# 260  Consolidated central government
# 261     Budgetary central government
# 262     Budgetary central government
#
#                        IMF data dissemination standard  \
# 0    Enhanced General Data Dissemination System (e-...
# 1    Enhanced General Data Dissemination System (e-...
# 2    Enhanced General Data Dissemination System (e-...
# 3    Enhanced General Data Dissemination System (e-...
# 4                                                  NaN
# ..                                                 ...
# 258  Enhanced General Data Dissemination System (e-...
# 259  Enhanced General Data Dissemination System (e-...
# 260         Special Data Dissemination Standard (SDDS)
# 261  Enhanced General Data Dissemination System (e-...
# 262  Enhanced General Data Dissemination System (e-...
#
#                               Latest population census  \
# 0                                                 2010
# 1                                                 1979
# 2                                                 2014
# 3                                                 2011
# 4    2011. Population data compiled from administra...
# ..                                                 ...
# 258                                               2011
# 259                                               2004
# 260                                               2011
# 261                                               2010
# 262                                               2012
#
#                         Latest household survey  \
# 0                                           NaN
# 1           Demographic and Health Survey, 2015
# 2        Demographic and Health Survey, 2015/16
# 3        Demographic and Health Survey, 2017/18
# 4                                           NaN
# ..                                          ...
# 258  Multiple Indicator Cluster Survey, 2013/14
# 259         Demographic and Health Survey, 2013
# 260         Demographic and Health Survey, 2016
# 261      Demographic and Health Survey, 2013/14
# 262         Demographic and Health Survey, 2015
#
#      Source of most recent Income and expenditure data  \
# 0                                                  NaN
# 1           Integrated household survey (IHS), 2016/17
# 2           Integrated household survey (IHS), 2008/09
# 3    Living Standards Measurement Study Survey (LSM...
# 4                                                  NaN
# ..                                                 ...
# 258     Expenditure survey/budget survey (ES/BS), 2015
# 259     Expenditure survey/budget survey (ES/BS), 2014
# 260  Expenditure survey/budget survey (ES/BS), 2014/15
# 261            Integrated household survey (IHS), 2015
# 262         Integrated household survey (IHS), 2011/12
#
#     Vital registration complete Latest agricultural census  \
# 0                           Yes                        NaN
# 1                           NaN                        NaN
# 2                           NaN                        NaN
# 3                           Yes                       2012
# 4                           Yes                        NaN
# ..                          ...                        ...
# 258                         NaN                       2014
# 259                         NaN                        NaN
# 260                         NaN                       2007
# 261                         NaN                        NaN
# 262                         NaN                        NaN
#
#     Latest industrial data Latest trade data Unnamed: 30
# 0                      NaN            2016.0         NaN
# 1                      NaN            2017.0         NaN
# 2                      NaN            2017.0         NaN
# 3                   2013.0            2017.0         NaN
# 4                      NaN               NaN         NaN
# ..                     ...               ...         ...
# 258                    NaN               NaN         NaN
# 259                 2012.0            2017.0         NaN
# 260                 2010.0            2017.0         NaN
# 261                 1994.0            2017.0         NaN
# 262                    NaN            2017.0         NaN
#
# [263 rows x 31 columns]

# %%
regCodes = WDICountry[WDICountry["Region"].isnull()]["Country Code"]
countryCodes = WDICountry[~WDICountry["Region"].isnull()]["Country Code"]
Emissions_C_df = EmissionsMeltClean[EmissionsMeltClean["Country Code"].isin(countryCodes)].copy()
Emissions_R_df = EmissionsMeltClean[EmissionsMeltClean["Country Code"].isin(regCodes)].copy()

Emissions_C_df.head()
# Out:
#      Country Name Country Code  \
# 1981  Afghanistan          AFG
# 1982  Afghanistan          AFG
# 1984  Afghanistan          AFG
# 1985  Afghanistan          AFG
# 1986  Afghanistan          AFG
#
#                                          Indicator Name     Indicator Code  \
# 1981                                 CO2 emissions (kt)     EN.ATM.CO2E.KT
# 1982             CO2 emissions (metric tons per capita)     EN.ATM.CO2E.PC
# 1984  CO2 emissions from gaseous fuel consumption (%...  EN.ATM.CO2E.GF.ZS
# 1985   CO2 emissions from gaseous fuel consumption (kt)  EN.ATM.CO2E.GF.KT
# 1986  CO2 emissions from liquid fuel consumption (% ...  EN.ATM.CO2E.LF.ZS
#
#       year  Indicator Value
# 1981  1960       414.371000
# 1982  1960         0.046057
# 1984  1960         0.000000
# 1985  1960         0.000000
# 1986  1960        65.486726

# %% [markdown]
# -------

# %% [markdown]
# ## Finalizing the cleaning for our study
#
# Our data has improved a lot by now. However, since the number of indicators is still quite large, let us focus our study on the following indicators for now:
#
# - **Total greenhouse gas emissions (kt of CO2 equivalent), EN.ATM.GHGT.KT.CE**: The total of greenhouse emissions includes CO2, Methane, Nitrous oxide, among other pollutant gases. Measured in kilotons.
#
#
# - **CO2 emissions (kt), EN.ATM.CO2E.KT**: Carbon dioxide emissions are those stemming from the burning of fossil fuels and the manufacture of cement. They include carbon dioxide produced during consumption of solid, liquid, and gas fuels and gas flaring.
#
#
# - **Methane emissions (kt of CO2 equivalent), EN.ATM.METH.KT.CE**: Methane emissions are those stemming from human activities such as agriculture and from industrial methane production.
#
#
# - **Nitrous oxide emissions (kt of CO2 equivalent), EN.ATM.NOXE.KT.CE**: Nitrous oxide emissions are emissions from agricultural biomass burning, industrial activities, and livestock management.
#
#
# - **Other greenhouse gas emissions, HFC, PFC and SF6 (kt of CO2 equivalent), EN.ATM.GHGO.KT.CE**: Other pollutant gases.
#
#
# - **PM2.5 air pollution, mean annual exposure (micrograms per cubic meter), EN.ATM.PM25.MC.M3**: Population-weighted exposure to ambient PM2.5 pollution is defined as the average level of exposure of a nation's population to concentrations of suspended particles measuring less than 2.5 microns in aerodynamic diameter, which are capable of penetrating deep into the respiratory tract and causing severe health damage. Exposure is calculated by weighting mean annual concentrations of PM2.5 by population in both urban and rural areas.
#
#
# - **PM2.5 air pollution, population exposed to levels exceeding WHO guideline value (% of total), EN.ATM.PM25.MC.ZS**: Percent of population exposed to ambient concentrations of PM2.5 that exceed the World Health Organization (WHO) guideline value.

# %% [markdown]
# ### Exercise 6:
#
# For each of the emissions DataFrames, extract the rows corresponding to the above indicators of interest. Replace the long names of the indicators by the short names ```Total```, ```CO2```, ```CH4```, ```N2O```, ```Other```, ```PM2.5```, and ```PM2.5_WHO```. (This will be helpful later when we need to label plots of our data.)

# %% [markdown]
# **Answer.**

# %%
replacementDir = {
    "EN.ATM.GHGT.KT.CE":"Total",
    "EN.ATM.CO2E.KT":"CO2",
    "EN.ATM.METH.KT.CE":"CH4",
    "EN.ATM.NOXE.KT.CE":"N2O",
    "EN.ATM.GHGO.KT.CE":"Other",
    "EN.ATM.PM25.MC.M3":"PM2.5",
    "EN.ATM.PM25.MC.ZS":"PM2.5_WHO"
    
    
}
replacementDir

Emissions_C_df = Emissions_C_df.replace(replacementDir)

Emissions_R_df = Emissions_R_df.replace(replacementDir)

# %%
Emissions_C_df = Emissions_C_df[Emissions_C_df["Indicator Code"].isin(replacementDir.values())]
print(Emissions_C_df.shape)
Emissions_R_df = Emissions_R_df[Emissions_R_df["Indicator Code"].isin(replacementDir.values())]
print(Emissions_R_df.shape)
# Out:
# (48059, 6)
# (11419, 6)

# %% [markdown]
# ---------

# %% [markdown]
# ## Where shall the client start environmental campaigns?
#
# Now the DataFrames ```Emissions_C_df``` and ```Emissions_R_df``` seem to be in a good shape. Let's proceed to conduct some exploratory data analysis so that we can make recommendations to our client.

# %% [markdown]
# ### Exercise 7:
#
#  Let's first calculate some basic information about the main indicators across the globe.
#
# #### 7.1
# Compute some basic statistics of the amount of kt of emissions for each of the four main pollutants (```CO2, CH4, N2O, Others```) over the years. Use the ```Emissions_C_df``` data frame. What trends do you see?

# %% [markdown]
# **Answer.**
# the most polluted countries are US, China, India... As expected.

# %%
countryStatistics = Emissions_C_df.groupby(["Country Name","Indicator Code"]).describe().reset_index()

# %%
countryStatistics = countryStatistics[countryStatistics["Indicator Code"].isin(["CO2","CH4","N2O","Other"])]
countryStatistics = countryStatistics.sort_values(by=["Indicator Code",("Indicator Value","50%")],ascending=False)
countryStatistics
# Out:
#                   Country Name Indicator Code Indicator Value                 \
#                                                         count           mean
# 294           Congo, Dem. Rep.          Other            43.0  874339.129589
# 179                     Brazil          Other            43.0  868419.064235
# 881                    Myanmar          Other            43.0  457841.521272
# 1050        Russian Federation          Other            43.0  443846.773869
# 597                  Indonesia          Other            43.0  563182.011916
# ...                        ...            ...             ...            ...
# 1292  Turks and Caicos Islands            CH4            43.0       2.966931
# 892                      Nauru            CH4            43.0       2.043535
# 975                      Palau            CH4            43.0       1.076359
# 692                     Kosovo            CH4             1.0       0.000000
# 859                 Montenegro            CH4             1.0       0.000000
#
#                                                                   \
#                 std            min            25%            50%
# 294   216213.058482  553036.491529  706210.901701  861357.502654
# 179   364168.633848  231242.270062  683228.568406  800860.002406
# 881   264818.566821   41136.796672  223188.624799  513917.219168
# 1050  200803.358597  130455.996875  352179.549180  417526.203125
# 597   636455.908231   10658.266180  153049.093530  366356.141797
# ...             ...            ...            ...            ...
# 1292       1.568947       1.316040       1.515955       2.395280
# 892        0.668495       1.099070       1.432925       1.993500
# 975        0.259883       0.596744       0.798685       1.151790
# 692             NaN       0.000000       0.000000       0.000000
# 859             NaN       0.000000       0.000000       0.000000
#
#
#                 75%           max
# 294   991033.314382  1.557937e+06
# 179   899476.267324  1.845285e+06
# 881   640193.271501  1.093226e+06
# 1050  463056.450000  1.226665e+06
# 597   731234.073047  3.484920e+06
# ...             ...           ...
# 1292       4.163665  6.125498e+00
# 892        2.616330  3.211225e+00
# 975        1.317795  1.360690e+00
# 692        0.000000  0.000000e+00
# 859        0.000000  0.000000e+00
#
# [815 rows x 10 columns]

# %%
mostPolutedCountries = {key: values["Country Name"][:5] for key,values in countryStatistics.groupby("Indicator Code")}
mostPolutedCountries
# Out:
# {'CH4': 270                  China
#  1330         United States
#  587                  India
#  1047    Russian Federation
#  176                 Brazil
#  Name: Country Name, dtype: object,
#  'CO2': 1331         United States
#  271                  China
#  1048    Russian Federation
#  644                  Japan
#  483                Germany
#  Name: Country Name, dtype: object,
#  'N2O': 272                  China
#  1332         United States
#  589                  India
#  178                 Brazil
#  1049    Russian Federation
#  Name: Country Name, dtype: object,
#  'Other': 294       Congo, Dem. Rep.
#  179                 Brazil
#  881                Myanmar
#  1050    Russian Federation
#  597              Indonesia
#  Name: Country Name, dtype: object}

# %%
mainPollutants = ["CO2","CH4","N2O","Other"]
isMainPollutant = Emissions_C_df["Indicator Code"].isin(mainPollutants)
mainPollutant_df = Emissions_C_df[isMainPollutant]
mainPollutant_df
# Out:
#                Country Name Country Code      Indicator Name Indicator Code  \
# 1981            Afghanistan          AFG  CO2 emissions (kt)            CO2
# 2023                Albania          ALB  CO2 emissions (kt)            CO2
# 2065                Algeria          DZA  CO2 emissions (kt)            CO2
# 2191                 Angola          AGO  CO2 emissions (kt)            CO2
# 2233    Antigua and Barbuda          ATG  CO2 emissions (kt)            CO2
# ...                     ...          ...                 ...            ...
# 609553        Venezuela, RB          VEN  CO2 emissions (kt)            CO2
# 609595              Vietnam          VNM  CO2 emissions (kt)            CO2
# 609721          Yemen, Rep.          YEM  CO2 emissions (kt)            CO2
# 609763               Zambia          ZMB  CO2 emissions (kt)            CO2
# 609805             Zimbabwe          ZWE  CO2 emissions (kt)            CO2
#
#         year  Indicator Value
# 1981    1960          414.371
# 2023    1960         2024.184
# 2065    1960         6160.560
# 2191    1960          550.050
# 2233    1960           36.670
# ...      ...              ...
# 609553  2014       185220.170
# 609595  2014       166910.839
# 609721  2014        22698.730
# 609763  2014         4503.076
# 609805  2014        12020.426
#
# [35342 rows x 6 columns]

# %% [markdown]
# #### Plotting all the countries

# %%
plt.figure(figsize=(18,20))

for i,indicator in enumerate(mainPollutants):
    plt.subplot(4,1,i+1)
    
    for country in mainPollutant_df["Country Name"].unique():
        isFromIndicator = mainPollutant_df["Indicator Code"] == indicator
        isFromCountry = mainPollutant_df["Country Name"] == country
        countryData = mainPollutant_df[isFromCountry & isFromIndicator]
        plt.plot(countryData["year"],countryData["Indicator Value"])

    _ = plt.xticks(rotation=90)
    plt.title(indicator)
    plt.tight_layout()
# plt.legend()

# %% [markdown]
# #### The most poluted countries on each indicator

# %%
plt.figure(figsize=(18,20))

for i,indicator in enumerate(mainPollutants):
    plt.subplot(4,1,i+1)
    
    for country in mostPolutedCountries[indicator]:
        isFromIndicator = mainPollutant_df["Indicator Code"] == indicator
        isFromCountry = mainPollutant_df["Country Name"] == country
        countryData = mainPollutant_df[isFromCountry & isFromIndicator]
        plt.plot(countryData["year"],countryData["Indicator Value"],label=country)

    _ = plt.xticks(rotation=90)
    plt.title("Top 5 on {}".format(indicator))
    plt.tight_layout()
    plt.legend()

# %% [markdown]
# #### Indicator of all the countries together

# %%
ax = plt.figure(figsize=(20,10))
g = sns.FacetGrid(data=mainPollutant_df,row="Indicator Code",height=1.7, aspect=8,sharex=False, sharey=False)
g = g.map(sns.lineplot,"year","Indicator Value")

for ax in g.axes.flat:
    for label in ax.get_xticklabels():
        label.set_rotation(90)
        
g.fig.tight_layout()

# %%
ax = plt.figure(figsize=(20,10))
sns.lineplot(x="year",y="Indicator Value",hue="Indicator Code",data=mainPollutant_df)
_ = plt.xticks(rotation=90)

# %% [markdown]
# ---------

# %% [markdown]
# #### 7.2
#
# What can you say about the *distribution* of emissions around the globe over the years? What information can you extract from the *tails* of these distributions over the years?

# %% [markdown]
# **Answer.**
#
# As we see in the following plot and supporting it with the above ones, we can see that there are some super high values, especially on CO2 measures and apparently they are caused by just a couple (one or two) countries.
#
# The moment we hide outliers we can appreciate that most of the medians are the same but the variation tends to increase over time, especially on Co2 indicator.

# %% [markdown]
# #### With outliers

# %%
g = sns.FacetGrid(data=mainPollutant_df,row="Indicator Code",height=5, aspect=3,sharex=False, sharey=False)
g = g.map(sns.boxplot,"year","Indicator Value")

for ax in g.axes.flat:
    for label in ax.get_xticklabels():
        label.set_rotation(90)
        
g.fig.tight_layout()

# %% [markdown]
# #### Without outliers

# %%
g = sns.FacetGrid(data=mainPollutant_df,row="Indicator Code",height=5, aspect=3,sharex=False, sharey=False)
g = g.map(sns.boxplot,"year","Indicator Value", showfliers=False)

for ax in g.axes.flat:
    for label in ax.get_xticklabels():
        label.set_rotation(90)
        
g.fig.tight_layout()

# %% [markdown]
# ---------

# %% [markdown]
# #### 7.3
# Compute a plot showing the behavior of each of the four main air pollutants for each of the main global regions in the ```Emissions_R_df``` data frame. The main regions are ```'Latin America & Caribbean', 'South Asia', 'Sub-Saharan Africa', 'Europe & Central Asia', 'Middle East & North Africa', 'East Asia & Pacific'``` and ```'North America'```. What conclusions can you make?

# %% [markdown]
# **Answer.**
#
# Most of the time `East Asia & Pacific (Blue)` and `Europe & Central Asia (Pink)` are on top of the others and `Middle East & North Africa (Green)` and `Sub-Saharan Africa (Purple)` are the least polluted in almost all categories.

# %%
mainRegions = ['Latin America & Caribbean', 'South Asia', 'Sub-Saharan Africa', 'Europe & Central Asia', 'Middle East & North Africa', 'East Asia & Pacific' , 'North America']

isMainRegion = Emissions_R_df["Country Name"].isin(mainRegions)
isMainPollutant = Emissions_R_df["Indicator Code"].isin(mainPollutants)
mainPollutant_R_df = Emissions_R_df[isMainRegion & isMainPollutant].copy()
mainPollutant_R_df
# Out:
#                       Country Name Country Code      Indicator Name  \
# 175            East Asia & Pacific          EAS  CO2 emissions (kt)
# 889      Latin America & Caribbean          LCN  CO2 emissions (kt)
# 1183    Middle East & North Africa          MEA  CO2 emissions (kt)
# 1351                 North America          NAC  CO2 emissions (kt)
# 1687                    South Asia          SAS  CO2 emissions (kt)
# ...                            ...          ...                 ...
# 599641   Latin America & Caribbean          LCN  CO2 emissions (kt)
# 599935  Middle East & North Africa          MEA  CO2 emissions (kt)
# 600103               North America          NAC  CO2 emissions (kt)
# 600439                  South Asia          SAS  CO2 emissions (kt)
# 600523          Sub-Saharan Africa          SSF  CO2 emissions (kt)
#
#        Indicator Code  year  Indicator Value
# 175               CO2  1960     1.210072e+06
# 889               CO2  1960     2.912526e+05
# 1183              CO2  1960     1.022525e+05
# 1351              CO2  1960     3.083749e+06
# 1687              CO2  1960     1.394877e+05
# ...               ...   ...              ...
# 599641            CO2  2014     1.912532e+06
# 599935            CO2  2014     2.593274e+06
# 600103            CO2  2014     5.792049e+06
# 600439            CO2  2014     2.516435e+06
# 600523            CO2  2014     8.228190e+05
#
# [1256 rows x 6 columns]

# %%
g = sns.FacetGrid(data=mainPollutant_R_df,row="Indicator Code",hue="Country Name",height=5, aspect=3,sharex=False, sharey=False)
g = g.map(sns.lineplot,"year","Indicator Value")

for ax in g.axes.flat:
    for label in ax.get_xticklabels():
        label.set_rotation(90)
    ax.legend()
g.fig.tight_layout()

# %% [markdown]
# ---------

# %% [markdown]
# ### Exercise 8:
#
# In Exercise 7 we discovered some interesting features of the distribution of the emissions over the years. Let us explore these features in more detail.

# %% [markdown]
# #### 8.1
# Which are the top five countries that have been in the top 10 of ```CO2``` emitters over the years? Have any of these countries made efforts to reduce the amount of CO2 emissions over the last 10 years?

# %% [markdown]
# **Answer.**
# US, Russia japan and germany and china are the most polluted in terms of CO2. The first four seems to decrease in the last 10 years, apparenttly the are doing an effort to decrease it or at least to avoid increasing it; in the other hand, china is is till increasing even more than before.

# %%
mostPolutedCountries

plt.figure(figsize=(15,8))

indicator = "CO2"
for country in mostPolutedCountries[indicator]:
    isFromIndicator = mainPollutant_df["Indicator Code"] == indicator
    isFromCountry = mainPollutant_df["Country Name"] == country
    countryData = mainPollutant_df[isFromCountry & isFromIndicator]
    plt.plot(countryData["year"],countryData["Indicator Value"],label=country)

_ = plt.xticks(rotation=90)
plt.title("Top 5 on {}".format(indicator))
plt.tight_layout()
plt.legend()

# %% [markdown]
# ---------

# %% [markdown]
# #### 8.2
#
# Are these five countries carrying out the burden of most of the emissions emitted over the years globally? Can we say that the rest of the world is making some effort to control their polluted gasses emissions over the years?

# %% [markdown]
# **Answer.**
#
# Apparently, yes

# %% [markdown]
# ---------

# %% [markdown]
# ## The health impacts of air pollution

# %% [markdown]
# ### Exercise 9:
#
# One of the main contributions of poor health from air pollution is particulate matter. In particular, very small particles (those with a size less than 2.5 micrometres ($\mu$m)) can enter and affect the respiratory system. The ```PM2.5``` indicator measures the average level of exposure of a nation's population to concentrations of these small particles. The ```PM2.5_WHO``` measures the  percentage of the population who are exposed to ambient concentrations of these particles that exceed some thresholds set by the World Health Organization (WHO). In particular, countries with a higher ```PM2.5_WHO``` indicator are more likely to suffer from bad health conditions.
#
#
# #### 9.1
#
# The client would like to know if there is any relationship between the ```PM2.5_WHO``` indicator and the level of income of the general population, as well as how this changes over time. What plot(s) might be helpful to solve the client's question?  What conclusion can you draw from your plot(s) to answer their question?
#
# **Hint:** The DataFrame ```WDI_countries``` contains a column named ```Income Group```.

# %% [markdown]
# **Answer.**
#
# Apparently, income groups are  related  with PM 2.5 Who indicator, seems to be, the more incomes the less indicator, but there is not too much difference

# %%
Emissions_C_df["Income Group"] = Emissions_C_df["Country Code"].apply(lambda x: WDICountry[WDICountry["Country Code"] == x]["Income Group"].iloc[0])

# Emissions_C_df

# %%
Emissions_C_df
# Out:
#                Country Name Country Code  \
# 1981            Afghanistan          AFG
# 2023                Albania          ALB
# 2065                Algeria          DZA
# 2191                 Angola          AGO
# 2233    Antigua and Barbuda          ATG
# ...                     ...          ...
# 643013          Yemen, Rep.          YEM
# 643054               Zambia          ZMB
# 643055               Zambia          ZMB
# 643096             Zimbabwe          ZWE
# 643097             Zimbabwe          ZWE
#
#                                            Indicator Name Indicator Code  \
# 1981                                   CO2 emissions (kt)            CO2
# 2023                                   CO2 emissions (kt)            CO2
# 2065                                   CO2 emissions (kt)            CO2
# 2191                                   CO2 emissions (kt)            CO2
# 2233                                   CO2 emissions (kt)            CO2
# ...                                                   ...            ...
# 643013  PM2.5 air pollution, population exposed to lev...      PM2.5_WHO
# 643054  PM2.5 air pollution, mean annual exposure (mic...          PM2.5
# 643055  PM2.5 air pollution, population exposed to lev...      PM2.5_WHO
# 643096  PM2.5 air pollution, mean annual exposure (mic...          PM2.5
# 643097  PM2.5 air pollution, population exposed to lev...      PM2.5_WHO
#
#         year  Indicator Value         Income Group
# 1981    1960       414.371000           Low income
# 2023    1960      2024.184000  Upper middle income
# 2065    1960      6160.560000  Upper middle income
# 2191    1960       550.050000  Lower middle income
# 2233    1960        36.670000          High income
# ...      ...              ...                  ...
# 643013  2017       100.000000           Low income
# 643054  2017        27.438035  Lower middle income
# 643055  2017       100.000000  Lower middle income
# 643096  2017        22.251671  Lower middle income
# 643097  2017       100.000000  Lower middle income
#
# [48059 rows x 7 columns]

# %%
isPM25W = Emissions_C_df["Indicator Code"]  == "PM2.5_WHO"

# %%
result = Emissions_C_df[isPM25W].groupby("Income Group").mean()
result = result.sort_values(by="Indicator Value")
result.plot(kind="bar")
result
# Out:
#                      Indicator Value
# Income Group
# High income                77.184224
# Upper middle income        98.591258
# Lower middle income        99.844565
# Low income                100.000000

# %%
# result = Emissions_C_df[isPM25W].groupby("Income Group").mean()
# result = result.sort_values(by="Indicator Value")
plt.figure(figsize=(15,5))
sns.lineplot(data=Emissions_C_df[isPM25W],x="year",y="Indicator Value", hue="Income Group")
# result.plot(kind="bar")
result
# Out:
#                      Indicator Value
# Income Group
# High income                77.184224
# Upper middle income        98.591258
# Lower middle income        99.844565
# Low income                100.000000

# %% [markdown]
# ---------

# %% [markdown]
# #### 9.2
#
# What do you think are the causes behind the results in Exercise 9.1?

# %% [markdown]
# **Answer.**
# Maybe countries with higher incomes can invest more on take care of air pollution

# %% [markdown]
# ---------

# %% [markdown]
# ### Exercise 10:
#
# Finally, our client is interested in investigating the impacts and relationships between **high levels of exposure to particle matter** and **the health of the population**. Coming up with additional data for this task may be infeasible for the client, thus they have asked us to search for relevant health data in the ```WDIdata.csv``` file and work with that.

# %% [markdown]
# #### 10.1
#
# Which indicators present in the file  ```WDISeries.csv``` file might be useful to solve the client's question? Explain.
#
# **Note:** Naming one or two indicators is more than enough for this question.
#
# **Answer:**
# The mortality rate on males and females caused by air pollution can be useful, as well as the mortality rate on all the population

# %%
isHealth = WDI_ids.Topic.str.lower().str.startswith("health")
isPolluted = WDI_ids["Indicator Name"].str.lower().str.contains("air")


print(*WDI_ids[isHealth & isPolluted]["Indicator Name"],sep="\n")
WDI_ids[isHealth & isPolluted]
#SH.STA.AIRP.FE.P5	 -- Mortality rate attributed to household and ambient air pollution, age-standardized, female (per 100,000 female population)
#SH.STA.AIRP.MA.P5	--  Mortality rate attributed to household and ambient air pollution, age-standardized, male (per 100,000 male population)
#SH.STA.AIRP.P5	    --  Mortality rate attributed to household and ambient air pollution, age-standardized (per 100,000 population)
# Out:
# Mortality rate attributed to household and ambient air pollution, age-standardized, female (per 100,000 female population)
# Mortality rate attributed to household and ambient air pollution, age-standardized, male (per 100,000 male population)
# Mortality rate attributed to household and ambient air pollution, age-standardized (per 100,000 population)
#            Series Code              Topic  \
# 984  SH.STA.AIRP.FE.P5  Health: Mortality
# 985  SH.STA.AIRP.MA.P5  Health: Mortality
# 986     SH.STA.AIRP.P5  Health: Mortality
#
#                                         Indicator Name Short definition  \
# 984  Mortality rate attributed to household and amb...              NaN
# 985  Mortality rate attributed to household and amb...              NaN
# 986  Mortality rate attributed to household and amb...              NaN
#
#                                        Long definition Unit of measure  \
# 984  Mortality rate attributed to household and amb...             NaN
# 985  Mortality rate attributed to household and amb...             NaN
# 986  Mortality rate attributed to household and amb...             NaN
#
#     Periodicity Base Period Other notes Aggregation method  ...  \
# 984      Annual         NaN         NaN   Weighted average  ...
# 985      Annual         NaN         NaN   Weighted average  ...
# 986      Annual         NaN         NaN   Weighted average  ...
#
#     Notes from original source General comments  \
# 984                        NaN              NaN
# 985                        NaN              NaN
# 986                        NaN              NaN
#
#                                                 Source  \
# 984  World Health Organization, Global Health Obser...
# 985  World Health Organization, Global Health Obser...
# 986  World Health Organization, Global Health Obser...
#
#     Statistical concept and methodology  \
# 984                                 NaN
# 985                                 NaN
# 986                                 NaN
#
#                                  Development relevance Related source links  \
# 984  Air pollution is one of the biggest environmen...                  NaN
# 985  Air pollution is one of the biggest environmen...                  NaN
# 986  Air pollution is one of the biggest environmen...                  NaN
#
#     Other web links  Related indicators License Type Unnamed: 20
# 984             NaN                 NaN    CC BY-4.0         NaN
# 985             NaN                 NaN    CC BY-4.0         NaN
# 986             NaN                 NaN    CC BY-4.0         NaN
#
# [3 rows x 21 columns]

# %% [markdown]
# ---------

# %% [markdown]
# #### 10.2
#
# Use the indicators provided in Exercise 10.1 to give valuable information to the client.

# %% [markdown]
# **Answer.**
#
# Unfortunately there is just information from 2016, for both, countries and regions

# %%
healthCodes = ["SH.STA.AIRP.FE.P5","SH.STA.AIRP.MA.P5","SH.STA.AIRP.P5"]
idVars = ['Country Name', 'Country Code', 'Indicator Name', 'Indicator Code']
valueVars = ['1960', '1961', '1962', '1963', '1964', '1965', '1966', '1967', '1968',
       '1969', '1970', '1971', '1972', '1973', '1974', '1975', '1976', '1977',
       '1978', '1979', '1980', '1981', '1982', '1983', '1984', '1985', '1986',
       '1987', '1988', '1989', '1990', '1991', '1992', '1993', '1994', '1995',
       '1996', '1997', '1998', '1999', '2000', '2001', '2002', '2003', '2004',
       '2005', '2006', '2007', '2008', '2009', '2010', '2011', '2012', '2013',
       '2014', '2015', '2016', '2017', '2018', '2019', 'Unnamed: 64']



healtMel_df = WDI_data[WDI_data["Indicator Code"].isin(healthCodes)].melt(idVars,valueVars,"year","Indicator Value").copy()
healtMel_df
# Out:
#                  Country Name Country Code  \
# 0                  Arab World          ARB
# 1                  Arab World          ARB
# 2                  Arab World          ARB
# 3      Caribbean small states          CSS
# 4      Caribbean small states          CSS
# ...                       ...          ...
# 48307                  Zambia          ZMB
# 48308                  Zambia          ZMB
# 48309                Zimbabwe          ZWE
# 48310                Zimbabwe          ZWE
# 48311                Zimbabwe          ZWE
#
#                                           Indicator Name     Indicator Code  \
# 0      Mortality rate attributed to household and amb...     SH.STA.AIRP.P5
# 1      Mortality rate attributed to household and amb...  SH.STA.AIRP.FE.P5
# 2      Mortality rate attributed to household and amb...  SH.STA.AIRP.MA.P5
# 3      Mortality rate attributed to household and amb...     SH.STA.AIRP.P5
# 4      Mortality rate attributed to household and amb...  SH.STA.AIRP.FE.P5
# ...                                                  ...                ...
# 48307  Mortality rate attributed to household and amb...  SH.STA.AIRP.FE.P5
# 48308  Mortality rate attributed to household and amb...  SH.STA.AIRP.MA.P5
# 48309  Mortality rate attributed to household and amb...     SH.STA.AIRP.P5
# 48310  Mortality rate attributed to household and amb...  SH.STA.AIRP.FE.P5
# 48311  Mortality rate attributed to household and amb...  SH.STA.AIRP.MA.P5
#
#               year  Indicator Value
# 0             1960              NaN
# 1             1960              NaN
# 2             1960              NaN
# 3             1960              NaN
# 4             1960              NaN
# ...            ...              ...
# 48307  Unnamed: 64              NaN
# 48308  Unnamed: 64              NaN
# 48309  Unnamed: 64              NaN
# 48310  Unnamed: 64              NaN
# 48311  Unnamed: 64              NaN
#
# [48312 rows x 6 columns]

# %%
isUnnamed = healtMel_df["year"] == "Unnamed: 64"
isNa = healtMel_df["Indicator Value"].isna()

healtMel_df[isUnnamed & ~isNa]

healtMel_df = healtMel_df[~isUnnamed]

healtMel_df = healtMel_df.dropna()
replacement = {
    "SH.STA.AIRP.FE.P5": "MortalityRate_F",
    "SH.STA.AIRP.MA.P5":"MortalityRate_M",
    "SH.STA.AIRP.P5":"MortalityRate"
}

healtMel_df = healtMel_df.replace(replacement)
healtMel_df
# Out:
#                  Country Name Country Code  \
# 44352              Arab World          ARB
# 44353              Arab World          ARB
# 44354              Arab World          ARB
# 44355  Caribbean small states          CSS
# 44356  Caribbean small states          CSS
# ...                       ...          ...
# 45139                  Zambia          ZMB
# 45140                  Zambia          ZMB
# 45141                Zimbabwe          ZWE
# 45142                Zimbabwe          ZWE
# 45143                Zimbabwe          ZWE
#
#                                           Indicator Name   Indicator Code  \
# 44352  Mortality rate attributed to household and amb...    MortalityRate
# 44353  Mortality rate attributed to household and amb...  MortalityRate_F
# 44354  Mortality rate attributed to household and amb...  MortalityRate_M
# 44355  Mortality rate attributed to household and amb...    MortalityRate
# 44356  Mortality rate attributed to household and amb...  MortalityRate_F
# ...                                                  ...              ...
# 45139  Mortality rate attributed to household and amb...  MortalityRate_F
# 45140  Mortality rate attributed to household and amb...  MortalityRate_M
# 45141  Mortality rate attributed to household and amb...    MortalityRate
# 45142  Mortality rate attributed to household and amb...  MortalityRate_F
# 45143  Mortality rate attributed to household and amb...  MortalityRate_M
#
#        year  Indicator Value
# 44352  2016       101.932592
# 44353  2016        90.506530
# 44354  2016       114.047887
# 44355  2016        42.299061
# 44356  2016        34.897602
# ...     ...              ...
# 45139  2016       121.000000
# 45140  2016       134.000000
# 45141  2016       133.000000
# 45142  2016       133.000000
# 45143  2016       133.000000
#
# [687 rows x 6 columns]

# %%
Health_C_df = healtMel_df[healtMel_df["Country Code"].isin(countryCodes)].copy()
Health_R_df = healtMel_df[healtMel_df["Country Code"].isin(regCodes)].copy()

# %%
Health_C_df.year.value_counts()
# Out:
# 2016    549
# Name: year, dtype: int64

# %%
isMainRegion = Health_R_df["Country Name"].isin(mainRegions)
isMortalityPop = Health_R_df["Indicator Code"] == "MortalityRate"
Health_R_df[isMainRegion & isMortalityPop].sort_values(by="Indicator Value")[["Country Name","Indicator Value"]] \
    .plot(kind="bar",x="Country Name",y="Indicator Value")

# %% [markdown]
# ---------

# %% [markdown]
# #### 10.3
#
# Extend the analysis above to find some countries of interest. These are defined as
#
# * The countries that have a high mortality rate due to household and ambient air pollution, but with low PM2.5 exposure
# * The countries that have a low mortality rate due to household and ambient air pollution, but with high PM2.5 exposure

# %% [markdown]
# **Answer.**

# %%
lowerPM25Th, upperPM25Th = Emissions_C_df[Emissions_C_df["Indicator Code"] == "PM2.5"]["Indicator Value"].quantile([0.1,0.9])
lowerDeathRTh, upperDeathRTh = Health_C_df[Health_C_df["Indicator Code"] == "MortalityRate"]["Indicator Value"].quantile([0.1,0.9])
# lowerTh
# upperTh

highMortalityCountries = set(Health_C_df[Health_C_df["Indicator Value"] > upperDeathRTh]["Country Name"])
highMortalityCountries

lowMortalityCountries = set(Health_C_df[Health_C_df["Indicator Value"] < lowerDeathRTh]["Country Name"])
lowMortalityCountries

highPM25Countries = set(Emissions_C_df[Emissions_C_df["Indicator Value"] > upperPM25Th]["Country Name"])
highPM25Countries

lowPM25Countries = set(Emissions_C_df[Emissions_C_df["Indicator Value"] < lowerPM25Th]["Country Name"])
# lowPM25Countries
# Emissions_C_df

# %%
highMortalityCountries.intersection(lowPM25Countries)
# Out:
# {'Afghanistan',
#  'Burkina Faso',
#  'Chad',
#  "Cote d'Ivoire",
#  'Eritrea',
#  'Guinea-Bissau',
#  'Haiti',
#  'Korea, Dem. People’s Rep.',
#  'Lesotho',
#  'Nepal',
#  'Niger',
#  'Nigeria',
#  'Pakistan',
#  'Philippines',
#  'Somalia',
#  'Sudan',
#  'Yemen, Rep.'}

# %%
lowMortalityCountries.intersection(highPM25Countries)
# Out:
# {'Australia',
#  'Austria',
#  'Belgium',
#  'Brunei Darussalam',
#  'Canada',
#  'Cyprus',
#  'Denmark',
#  'Finland',
#  'France',
#  'Germany',
#  'Iceland',
#  'Ireland',
#  'Israel',
#  'Italy',
#  'Japan',
#  'Korea, Rep.',
#  'Luxembourg',
#  'Netherlands',
#  'New Zealand',
#  'Norway',
#  'Portugal',
#  'Spain',
#  'Sweden',
#  'Switzerland',
#  'United Kingdom',
#  'United States',
#  'Uruguay'}

# %% [markdown]
# ---------

# %% [markdown]
# #### 10.4
#
# Finally, we want to look at the mortality data by income. We expect higher income countries to have lower pollution-related mortality. Find out if this assumption holds. Calculate summary statistics and histograms for each income category and note any trends.

# %% [markdown]
# **Answer.**
#
# We could prove that the income group is directly related to the mortality rate.

# %%
Health_C_df
isMortalityPop = Health_C_df["Indicator Code"] == "MortalityRate"
Health_C_df["Income Group"] = Health_C_df["Country Code"].apply(lambda x: WDICountry[WDICountry["Country Code"] == x]["Income Group"].iloc[0])
groupedInfo = Health_C_df[isMortalityPop].groupby("Income Group").describe().sort_values(by=("Indicator Value","mean"))
groupedInfo[("Indicator Value","mean")].plot(kind="bar")
plt.ylabel("Mortality rate mean")
groupedInfo
# groupedInfo[("Indicator Value","mean")]
# Emissions_C_df
# Out:
#                     Indicator Value                                       \
#                               count        mean        std   min     25%
# Income Group
# High income                    52.0   25.142308  19.123534   7.0   11.90
# Upper middle income            54.0   63.937037  29.618125  23.3   46.80
# Lower middle income            46.0  136.441304  55.566699  41.9  101.85
# Low income                     31.0  188.341935  52.959341  75.2  157.65
#
#
#                        50%      75%    max
# Income Group
# High income           20.0   33.625  103.8
# Upper middle income   61.1   77.950  177.7
# Lower middle income  138.4  167.725  307.4
# Low income           193.8  212.350  324.1

# %% [markdown]
# ---------

# %% [markdown]
# #### 10.5
#
# At the start, we asked some questions. Based on your analysis, provide a short answer to each of these:
#
# 1. Are we making any progress in reducing the amount of emitted pollutants across the globe?
# 2. Which are the critical regions where we should start environmental campaigns?
# 3. Are we making any progress in the prevention of deaths related to air pollution?
# 4. Which demographic characteristics seem to correlate with the number of health-related issues derived from air pollution?

# %% [markdown]
# **Answer.**
#
#
# 1. Most of all the countries are behaving quite similar, with low air pollution, except for some countries that have a huge difference. One important aspect to highlight is most of the most air pollution producers are trying to decrease or avoid increases during the past 10 years except for china who is even increasing exponentially during this period.
#
# 2. As it was mentioned before, China is not aware the damage that is causing to the environment so It might be a good idea to start environmental campaigns mainly in that country in order to decrease the air pollution produced there or at least, at first, stopping the increasing curve of air pollution.
#
# 3.
#
# 4. It is clear the relationship between incomes and the mortality rate caused by air pollution.

# %% [markdown]
# ---------
