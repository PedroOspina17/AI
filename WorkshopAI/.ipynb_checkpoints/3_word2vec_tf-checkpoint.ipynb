# %%
import time
import pickle
import random
import operator
import numpy as np
import tensorflow as tf

# %% [markdown]
# ## Loading preprocessed data

# %%
with open('1.1_read_wikis.pickle', 'rb') as f:
    # Pickle the 'data' dictionary using the highest protocol available.
    (word2idx_counts, idx2word, sentences) = pickle.load(f)

# %%
len(sentences)
# Out:
# 18967367

# %% [markdown]
# ## Subsampling
#
# Words that show up often such as "the", "of", and "for" don't provide much context to the nearby words. If we discard some of them, we can remove some of the noise from our data and in return get faster training and better representations. This process is called subsampling by Mikolov. For each word $w_i$ in the training set, we'll discard it with probability given by
#
# $$ P(w_i) = 1 - \sqrt{\frac{t}{f(w_i)}} $$
#
# where $t$ is a threshold parameter and $f(w_i)$ is the frequency of word $w_i$ in the total dataset.
#
# I'm going to leave this up to you as an exercise. Check out my solution to see how I did it.
#
# ><img src="images/task.png" width="5%" height="5%">
#
# > **Exercise:** Complete subsampling function. That is, go through `word2idx` and discard each word given the probablility $P(w_i)$ shown above. Note that $P(w_i)$ is that probability that a word is discarded. Assign the subsampled data to `train_words`.

# %%
def subsampling(word2idx, idx2word, sentences, n_vocab, threshold = 1e-5):
        
    total_count = len(word2idx)
    
    # HERE you complete your code using the probability of sampled word
    train_words = word2idx
    #applying formula above
    freqs = {idx_word: count/total_count for idx_word, count in word2idx.items()}
    p_drop = {idx_word: 1 - np.sqrt(threshold/freqs[idx_word]) for idx_word in word2idx}
    train_words = {idx_word: word for idx_word, word in word2idx.items() if random.random() < (1 - p_drop[idx_word])}
    
    # restrict vocab size
    sorted_word_idx_count = sorted(train_words.items(), key=operator.itemgetter(1), reverse=True)
    word2idx_small = {}
    new_idx = 0
    idx_new_idx_map = {}
    for idx, count in sorted_word_idx_count[:n_vocab]:
        word = idx2word[idx]
        # print(word, count)
        word2idx_small[word] = new_idx
        idx_new_idx_map[idx] = new_idx
        new_idx += 1
    # let 'unknown' be the last token
    word2idx_small['UNKNOWN'] = new_idx
    idx2word_small = {v:k for k,v in word2idx_small.items()}
    unknown = new_idx

    #example_existence = ('king' in word2idx_small) | ('queen' in word2idx_small) | ('man' in word2idx_small) | (
     #           'woman' in word2idx_small)
    #print(example_existence)
    #if not example_existence:
     #   print("There is no example desired.")
      #  exit(1)

    # map old idx to new idx
    sentences_small = []
    for sentence in sentences:
        if len(sentence) > 1:
            new_sentence = [idx_new_idx_map[idx] if idx in idx_new_idx_map else unknown for idx in sentence]
            sentences_small.append(new_sentence)

    with open('1.2_subsampled_wikis.pickle', 'wb') as f:
        # Pickle the 'data' dictionary using the highest protocol available.
        pickle.dump((sentences_small, word2idx_small, idx2word_small), f, pickle.HIGHEST_PROTOCOL)

    return sentences_small, word2idx_small, idx2word_small

# %%
sentences_sampled, word2idx_sampled, idx2word_sampled  = subsampling(word2idx_counts, idx2word, sentences, n_vocab=10000)

# %%
# %time
with open('1.2_subsampled_wikis.pickle', 'rb') as f:
    # Pickle the 'data' dictionary using the highest protocol available.
    (sentences_sampled, word2idx_sampled, idx2word_sampled) = pickle.load(f)

# %%
[idx2word_sampled[word] for word in sentences_sampled[1]]

# %% [markdown]
# # Word2Vec: faking on a Neural Network
#
# Citing [Chris McCormick](http://mccormickml.com/2016/04/19/word2vec-tutorial-the-skip-gram-model/): "We’re going to train a simple neural network with a single hidden layer to perform a certain task, but then we’re not actually going to use that neural network for the task we trained it on! Instead, the goal is actually just to learn the weights of the hidden layer–we’ll see that these weights are actually the “word vectors” that we’re trying to learn."

# %% [markdown]
# ## Making batches: Skip-gram architecture

# %% [markdown]
# Now that our data is in good shape, we need to get it into the proper form to pass it into our network. With the skip-gram architecture, for each word in the text, we want to grab all the words in a window around that word, with size $C$.
#
# From [Mikolov et al.](https://arxiv.org/pdf/1301.3781.pdf):
#
# "Since the more distant words are usually less related to the current word than those close to it, we give less weight to the distant words by sampling less from those words in our training examples... If we choose $C = 5$, for each training word we will select randomly a number $R$ in range $< 1; C >$, and then use $R$ words from history and $R$ words from the future of the current word as correct labels."
#
# We’ll train the neural network creating a set of batches in order to feed it with word pairs, lets say input, target (word of context C). The example below shows some of the training samples (word pairs) we would take from the sentence “The quick brown fox jumps over the lazy dog.” Using a small window size of 2 just for the example. The word highlighted in blue is the input word.
#
# <img src="images/batch_arch.png" width="50%" height="50%">
#
# ><img src="images/task.png" width="5%" height="5%">
#
# > **Exercise:** Implement a function `get_target` that receives a list of words, an index, and a window size, then returns a list of words in the window around the index. Make sure to use the algorithm described above, where you chose a random number of words to from the window.

# %%
def get_target(idx2word, words, idx, window_size=5):
    ''' Get a list of words in a window around an index. '''
    
    R = np.random.randint(1, window_size+1)
    start = idx - R if (idx - R) > 0 else 0
    stop = idx + R
    target_words = set(words[start:idx] + words[idx+1:stop+1])
#     target_words = [idx2word[word] for word in target_words]
    return list(target_words)

# %% [markdown]
# Next, batches of sentences are returned for our network. The idea is that it grabs `batch_size` sentences from sentences list. Then for each of those sentences, iterates per sentence and it gets the target words in the window.

# %%
def get_batches(sentences, idx2word, batch_size, window_size=5):
    ''' Create a generator of word batches as a tuple (inputs, targets) '''
    
    n_batches = len(sentences)//batch_size
    
    #shuffles sentences
    random.shuffle(sentences)
    
    # only full batches
    sentences = sentences[:n_batches*batch_size]
    
    #for each batch of sentences    
    for idx in range(0, len(sentences), batch_size):
        x, y = [], []
        
        #gets batch of sentences
        batch = sentences[idx:idx+batch_size]
        
        #for each sentence in a batch
        for sentence in batch:
            
            #for each word in a sentence, gets its context
            for idx in range(len(sentence)):
#                 batch_x = idx2word[sentence[idx]]
                batch_x = sentence[idx]
                batch_y = get_target(idx2word, sentence, idx, window_size)
                y.extend(batch_y)
                x.extend([batch_x]*len(batch_y))
                
        # yields a batch
        yield x, y

# %%
generator = get_batches(sentences_sampled, idx2word_sampled, 500, 7)

# %%
x,y = next(generator)

# %%
x[:10]
# Out:
# [10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000, 10000]

# %%
len(word2idx_sampled)
# Out:
# 10001

# %% [markdown]
# ## Building the graph
#
# The general structure of our network is as follows:
#
# <img src="images/word2vec-skip-gram.png" width="50%" height="50%">
#
# The input words are passed in as one-hot encoded vectors. This will go into a hidden layer of linear units, then into a softmax layer. We'll use the softmax layer to make a prediction like normal.
#
# The idea here is to train the hidden layer weight matrix to find efficient representations for our words. We can discard the softmax layer becuase we don't really care about making predictions with this network (FAKE TASK!). We just want the embedding matrix so we can use it in other networks we build from the dataset.
#
# I'm going to have you build the graph in stages now. First off, creating the `inputs` and `labels` placeholders like normal.
#
# ><img src="images/task.png" width="5%" height="5%">
#
# > **Exercise:** Assign `inputs` and `labels` using `tf.placeholder`. We're going to be passing in integers, so set the data types to `tf.int32`. The batches we're passing in will have varying sizes, so set the batch sizes to [`None`]. To make things work later, you'll need to set the second dimension of `labels` to `None` or `1`.

# %%
train_graph = tf.Graph()
with train_graph.as_default():
    inputs = tf.placeholder(tf.int32, [None], name='inputs')
    labels = tf.placeholder(tf.int32, [None, 1], name='labels')

# %% [markdown]
# ## Embedding

# %% [markdown]
# The embedding matrix has a size of the number of words by the number of units in the hidden layer. So, if you have 10,000 words and 300 hidden units, the matrix will have size $10,000 \times 300$. Remember that we're using tokenized data for our inputs, usually as integers, where the number of tokens is the number of words in our vocabulary.
#
# <img src="images/matrix_mult_w_one_hot.png" width="50%" height="50%">
#
# Tensorflow provides a convenient function [`tf.nn.embedding_lookup`](https://www.tensorflow.org/api_docs/python/tf/nn/embedding_lookup) that does this *lookup* for us. You pass in the embedding matrix and a tensor of integers, then it returns rows in the matrix corresponding to those integers. Below, set the number of embedding features you'll use (200 is a good start), create the embedding matrix variable, and use `tf.nn.embedding_lookup` to get the embedding tensors. For the embedding matrix, to initialize it with a uniform random numbers between -1 and 1 we use [tf.random_uniform](https://www.tensorflow.org/api_docs/python/tf/random_uniform).

# %%
n_vocab = len(word2idx_sampled)
n_embedding = 500 # Number of embedding features 
with train_graph.as_default():
    embedding = tf.Variable(tf.random_uniform((n_vocab, n_embedding), -1, 1))
    embed = tf.nn.embedding_lookup(embedding, inputs)

# %% [markdown]
# ## Negative sampling

# %% [markdown]
# For every example we give the network, we train it using the output from the softmax layer. That means for each input, we're making very small changes to millions of weights even though we only have one true example. This makes training the network very inefficient. We can approximate the loss from the softmax layer by only updating a small subset of all the weights at once. We'll update the weights for the correct label, but only a small number of incorrect labels. This is called ["negative sampling"](http://papers.nips.cc/paper/5021-distributed-representations-of-words-and-phrases-and-their-compositionality.pdf). Tensorflow has a convenient function to do this, [`tf.nn.sampled_softmax_loss`](https://www.tensorflow.org/api_docs/python/tf/nn/sampled_softmax_loss).
#
# In the word2vec each word is given a weight equal to it’s frequency (word count) raised to the 3/4 power. The probability for a selecting a word is just it’s weight divided by the sum of weights for all words.
#
# $$ P(w_i) = \frac{  {f(w_i)}^{3/4}  }{\sum_{j=0}^{n}\left(  {f(w_j)}^{3/4} \right) } $$

# %%
# Number of negative labels to sample
n_sampled = 5
with train_graph.as_default():
    softmax_w = tf.Variable(tf.truncated_normal((n_vocab, n_embedding), stddev=0.1))
    softmax_b = tf.Variable(tf.zeros(n_vocab))
    
    # Calculate the loss using negative sampling
    loss = tf.nn.sampled_softmax_loss(softmax_w, softmax_b, 
                                      labels, embed,
                                      n_sampled, n_vocab)
    
    cost = tf.reduce_mean(loss)
    optimizer = tf.train.AdamOptimizer().minimize(cost)

# %% [markdown]
# ## Validation
#
# Here we're going to choose a few common words and few uncommon words. Then, we'll print out the closest words to them. It's a nice way to check that our embedding table is grouping together words with similar semantic meanings.

# %%
with train_graph.as_default():
    ## From Thushan Ganegedara's implementation
    valid_size = 16 # Random set of words to evaluate similarity on.
    valid_window = 100
    # pick 8 samples from (0,100) and (1000,1100) each ranges. lower id implies more frequent 
    valid_examples = np.array(random.sample(range(valid_window), valid_size//2))
    valid_examples = np.append(valid_examples, 
                               random.sample(range(1000,1000+valid_window), valid_size//2))

    valid_dataset = tf.constant(valid_examples, dtype=tf.int32)
    
    # We use the cosine distance:
    norm = tf.sqrt(tf.reduce_sum(tf.square(embedding), 1, keepdims=True))
    normalized_embedding = embedding / norm
    valid_embedding = tf.nn.embedding_lookup(normalized_embedding, valid_dataset)
    similarity = tf.matmul(valid_embedding, tf.transpose(normalized_embedding))

# %%
# If the checkpoints directory doesn't exist:
# !mkdir checkpoints
# Out:
# mkdir: cannot create directory ‘checkpoints’: File exists

# %% [markdown]
# # It's time to run alltogether

# %%
# %%time
epochs = 20
batch_size = 1000
window_size = 10

with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    iteration = 1
    loss = 0
    sess.run(tf.global_variables_initializer())

    for e in range(1, epochs+1):
        batches = get_batches(sentences_sampled, idx2word_sampled, batch_size, window_size)
        start = time.time()
        for x, y in batches:
            
            feed = {inputs: x,
                    labels: np.array(y)[:, None]}
            train_loss, _ = sess.run([cost, optimizer], feed_dict=feed)
            
            loss += train_loss
            
            if iteration % 100 == 0: 
                end = time.time()
                print("Epoch {}/{}".format(e, epochs),
                      "Iteration: {}".format(iteration),
                      "Avg. Training loss: {:.4f}".format(loss/100),
                      "{:.4f} sec/batch".format((end-start)/100))
                loss = 0
                start = time.time()
            
            if iteration % 1000 == 0:
                # note that this is expensive (~20% slowdown if computed every 500 steps)
                sim = similarity.eval()
                for i in range(valid_size):
                    valid_word = idx2word_sampled[valid_examples[i]]
                    top_k = 8 # number of nearest neighbors
                    nearest = (-sim[i, :]).argsort()[1:top_k+1]
                    log = 'Nearest to %s:' % valid_word
                    for k in range(top_k):
                        close_word = idx2word_sampled[nearest[k]]
                        log = '%s %s,' % (log, close_word)
                    print(log)
            
            iteration += 1
    
    sim = similarity.eval()
    for i in range(valid_size):
        valid_word = idx2word_sampled[valid_examples[i]]
        top_k = 8 # number of nearest neighbors
        nearest = (-sim[i, :]).argsort()[1:top_k+1]
        log = 'Nearest to %s:' % valid_word
        for k in range(top_k):
            close_word = idx2word_sampled[nearest[k]]
            log = '%s %s,' % (log, close_word)
        print(log)
                    
    save_path = saver.save(sess, "checkpoints/wikipedia.ckpt")
    embed_mat = sess.run(normalized_embedding)
# Out:
# Epoch 1/20 Iteration: 100 Avg. Training loss: 0.7773 0.7696 sec/batch
# Epoch 1/20 Iteration: 200 Avg. Training loss: 1.0342 0.4411 sec/batch
# Epoch 1/20 Iteration: 300 Avg. Training loss: 1.2137 0.3942 sec/batch
# Epoch 1/20 Iteration: 400 Avg. Training loss: 1.2994 0.4360 sec/batch
# Epoch 1/20 Iteration: 500 Avg. Training loss: 1.4477 0.4212 sec/batch
# Epoch 1/20 Iteration: 600 Avg. Training loss: 1.2547 0.3945 sec/batch
# Epoch 1/20 Iteration: 700 Avg. Training loss: 1.4360 0.4276 sec/batch
# Epoch 1/20 Iteration: 800 Avg. Training loss: 1.3385 0.3865 sec/batch
# Epoch 1/20 Iteration: 900 Avg. Training loss: 1.2964 0.4212 sec/batch
# Epoch 1/20 Iteration: 1000 Avg. Training loss: 1.2403 0.3855 sec/batch
# Nearest to 1906: trackers, splendid, ontology, hydrological, llm, arunachal, yorker, aperture,
# Nearest to worth: precisely, weep, classifies, jenks, kumari, orientalism, medically, shiga,
# Nearest to category: rbis, carly, 1515, mallard, sentence, neat, gk, dewsbury,
# Nearest to whilst: partridge, llm, gilroy, aso, podium, mugabe, ars, durbin,
# Nearest to frequency: time”, styling, shekhar, comune, vegetated, typhus, renovation, gibbons,
# Nearest to injury: lacks, zoological, paf, whimsical, climbs, ranchi, melodrama, cornerstone,
# Nearest to register: sinners, 053%, cc, bretton, compensation, frente, queensland&aposs, invalidated,
# Nearest to little: sweetened, vitesse, damato, storyline, 1102, prion, extremadura, fittings,
# Nearest to shakespeares: scrambling, gauges, dissociation, primitives, leadoff, overdue, nee, marthas,
# Nearest to irwin: corazon, sprung, pyrite, kwh, redesign, tallest, ste, seas,
# Nearest to invading: aquarium, peoples, whistler, excepting, stenosis, attainment, williamstown, sled,
# Nearest to 99%: sar, bistro, lombardi, ascot, lacks, paulista, brave, fortnight,
# Nearest to protector: chernivtsi, slovak, lungs, 69%, ppv, sacral, minolta, 200m,
# Nearest to reginald: bra, crore, spooky, bernice, almanac, spurious, equalled, songwriting,
# Nearest to polished: fisa, cricketers, nakhon, chevalier, seldom, 389, supermodel, palpi,
# Nearest to amplitude: clergyman, yeh, solitude, lessen, bullies, ob, brilliantly, ars,
# Epoch 1/20 Iteration: 1100 Avg. Training loss: 1.1871 0.4292 sec/batch
# Epoch 1/20 Iteration: 1200 Avg. Training loss: 1.0872 0.4058 sec/batch
# Epoch 1/20 Iteration: 1300 Avg. Training loss: 0.8823 0.4318 sec/batch
# Epoch 1/20 Iteration: 1400 Avg. Training loss: 0.9431 0.3801 sec/batch
# Epoch 1/20 Iteration: 1500 Avg. Training loss: 0.8303 0.3830 sec/batch
# Epoch 1/20 Iteration: 1600 Avg. Training loss: 0.7091 0.3922 sec/batch
# Epoch 1/20 Iteration: 1700 Avg. Training loss: 0.6551 0.4006 sec/batch
# Epoch 1/20 Iteration: 1800 Avg. Training loss: 0.6051 0.3639 sec/batch
# Epoch 1/20 Iteration: 1900 Avg. Training loss: 0.5940 0.3645 sec/batch
# Epoch 1/20 Iteration: 2000 Avg. Training loss: 0.5405 0.3763 sec/batch
# Nearest to 1906: trackers, ontology, splendid, hydrological, aperture, arunachal, yorker, shouting,
# Nearest to worth: classifies, precisely, weep, miner, orientalism, straps, medically, kumari,
# Nearest to category: rbis, carly, 1515, sentence, mallard, neat, 1310, $250,
# Nearest to whilst: partridge, gilroy, llm, podium, alegre, mugabe, gower, aso,
# Nearest to frequency: time”, styling, shekhar, comune, typhus, 165, gibbons, vegetated,
# Nearest to injury: lacks, zoological, paf, whimsical, melodrama, climbs, ranchi, gcse,
# Nearest to register: sinners, cc, 053%, compensation, bretton, gamers, frente, smyth,
# Nearest to little: sweetened, storyline, damato, vitesse, thorn, 1102, prion, fittings,
# Nearest to shakespeares: scrambling, gauges, dissociation, primitives, leadoff, overdue, coxswain, $200,
# Nearest to irwin: corazon, sprung, pyrite, tallest, ste, kwh, redesign, seas,
# Nearest to invading: peoples, attainment, stenosis, aquarium, whistler, excepting, williamstown, swansea,
# Nearest to 99%: sar, lombardi, bistro, ascot, lacks, paulista, brave, fortnight,
# Nearest to protector: chernivtsi, slovak, lungs, 69%, ppv, sacral, minolta, 200m,
# Nearest to reginald: bra, crore, bernice, spooky, spurious, almanac, equalled, songwriting,
# Nearest to polished: cricketers, nakhon, fisa, supermodel, seldom, chevalier, 99%, palpi,
# Nearest to amplitude: clergyman, yeh, solitude, lessen, bullies, brilliantly, jess, ars,
# Epoch 1/20 Iteration: 2100 Avg. Training loss: 0.5654 0.4877 sec/batch
# Epoch 1/20 Iteration: 2200 Avg. Training loss: 0.5181 0.4007 sec/batch
# Epoch 1/20 Iteration: 2300 Avg. Training loss: 0.4976 0.3690 sec/batch
# Epoch 1/20 Iteration: 2400 Avg. Training loss: 0.5051 0.4326 sec/batch
# Epoch 1/20 Iteration: 2500 Avg. Training loss: 0.5079 0.4044 sec/batch
# Epoch 1/20 Iteration: 2600 Avg. Training loss: 0.4823 0.3952 sec/batch
# Epoch 1/20 Iteration: 2700 Avg. Training loss: 0.4751 0.3928 sec/batch
# Epoch 1/20 Iteration: 2800 Avg. Training loss: 0.4777 0.4343 sec/batch
# Epoch 1/20 Iteration: 2900 Avg. Training loss: 0.4908 0.7614 sec/batch
# Epoch 1/20 Iteration: 3000 Avg. Training loss: 0.4947 0.7072 sec/batch
# Nearest to 1906: trackers, ontology, splendid, aperture, yorker, hydrological, shouting, underworld,
# Nearest to worth: classifies, precisely, miner, medically, weep, orientalism, straps, kumari,
# Nearest to category: rbis, sentence, 1515, carly, mallard, wrangler, 1310, neat,
# Nearest to whilst: partridge, gilroy, llm, podium, durbin, racquetball, gower, alegre,
# Nearest to frequency: styling, time”, shekhar, comune, 165, gibbons, typhus, renovation,
# Nearest to injury: lacks, zoological, climbs, gcse, ranchi, transylvanian, whimsical, paf,
# Nearest to register: compensation, cc, sinners, 053%, frente, bretton, gamers, invalidated,
# Nearest to little: sweetened, storyline, damato, thorn, vitesse, 1102, prion, 306%,
# Nearest to shakespeares: scrambling, gauges, dissociation, primitives, leadoff, overdue, svenska, coxswain,
# Nearest to irwin: corazon, pyrite, tallest, sprung, ste, kwh, redesign, mulligan,
# Nearest to invading: peoples, attainment, stenosis, aquarium, swansea, whistler, mallory, williamstown,
# Nearest to 99%: sar, lombardi, paulista, bistro, lacks, brave, ascot, aphids,
# Nearest to protector: chernivtsi, lungs, slovak, ppv, 69%, sacral, ramsay, schreiber,
# Nearest to reginald: bra, crore, spurious, bernice, songwriting, spooky, almanac, swansea,
# Nearest to polished: cricketers, fisa, nakhon, seldom, supermodel, chevalier, 99%, palpi,
# Nearest to amplitude: clergyman, solitude, yeh, lessen, bullies, jess, ars, brilliantly,
# Epoch 1/20 Iteration: 3100 Avg. Training loss: 0.4848 0.5064 sec/batch
# Epoch 1/20 Iteration: 3200 Avg. Training loss: 0.4669 0.4464 sec/batch
# Epoch 1/20 Iteration: 3300 Avg. Training loss: 0.4600 0.4750 sec/batch
# Epoch 1/20 Iteration: 3400 Avg. Training loss: 0.4432 0.4537 sec/batch
# Epoch 1/20 Iteration: 3500 Avg. Training loss: 0.4798 0.4838 sec/batch
# Epoch 1/20 Iteration: 3600 Avg. Training loss: 0.4754 0.5045 sec/batch
# Epoch 1/20 Iteration: 3700 Avg. Training loss: 0.4874 0.4583 sec/batch
# Epoch 1/20 Iteration: 3800 Avg. Training loss: 0.4693 0.4544 sec/batch
# Epoch 1/20 Iteration: 3900 Avg. Training loss: 0.4842 0.5462 sec/batch
# Epoch 1/20 Iteration: 4000 Avg. Training loss: 0.4607 0.5967 sec/batch
# Nearest to 1906: trackers, ontology, aperture, splendid, rong, yorker, hydrological, underworld,
# Nearest to worth: classifies, precisely, miner, medically, straps, weep, coverings, orientalism,
# Nearest to category: rbis, sentence, 1515, 1310, mallard, carly, ulcer, warmed,
# Nearest to whilst: partridge, llm, podium, gilroy, durbin, gower, racquetball, alegre,
# Nearest to frequency: styling, time”, shekhar, comune, 165, sie, gibbons, 8500,
# Nearest to injury: lacks, climbs, gcse, zoological, whimsical, transylvanian, nws, ranchi,
# Nearest to register: compensation, cc, frente, sinners, invalidated, firebox, 053%, tremendously,
# Nearest to little: sweetened, storyline, UNKNOWN, damato, vitesse, “for, thorn, fittings,
# Nearest to shakespeares: scrambling, gauges, dissociation, primitives, svenska, overdue, leadoff, wheel,
# Nearest to irwin: corazon, sprung, pyrite, tallest, kwh, redesign, ste, atman,
# Nearest to invading: peoples, attainment, stenosis, whistler, raffaele, mallory, williamstown, lapland,
# Nearest to 99%: sar, lombardi, bistro, lacks, paulista, aphids, ascot, brave,
# Nearest to protector: chernivtsi, lungs, slovak, ppv, sacral, 69%, frantic, baths,
# Nearest to reginald: crore, bra, spurious, bernice, songwriting, spooky, almanac, equalled,
# Nearest to polished: fisa, cricketers, 99%, supermodel, seldom, chevalier, psionic, palpi,
# Nearest to amplitude: clergyman, solitude, yeh, lessen, bullies, jess, ars, brilliantly,
# Epoch 1/20 Iteration: 4100 Avg. Training loss: 0.4675 0.5181 sec/batch
# Epoch 1/20 Iteration: 4200 Avg. Training loss: 0.4489 0.4907 sec/batch
# Epoch 1/20 Iteration: 4300 Avg. Training loss: 0.4888 0.4599 sec/batch
# Epoch 1/20 Iteration: 4400 Avg. Training loss: 0.4472 0.4491 sec/batch
# Epoch 1/20 Iteration: 4500 Avg. Training loss: 0.4594 0.4869 sec/batch
# Epoch 1/20 Iteration: 4600 Avg. Training loss: 0.4853 0.4369 sec/batch
# Epoch 1/20 Iteration: 4700 Avg. Training loss: 0.4678 0.4550 sec/batch
# Epoch 1/20 Iteration: 4800 Avg. Training loss: 0.4820 0.4445 sec/batch
# Epoch 1/20 Iteration: 4900 Avg. Training loss: 0.4530 0.4279 sec/batch
# Epoch 1/20 Iteration: 5000 Avg. Training loss: 0.4757 0.4310 sec/batch
# Nearest to 1906: trackers, ontology, aperture, yorker, rong, splendid, llm, hydrological,
# Nearest to worth: classifies, miner, medically, precisely, straps, weep, yume, kumari,
# Nearest to category: sentence, rbis, 1310, 1515, carly, mallard, ulcer, warmed,
# Nearest to whilst: partridge, llm, durbin, gilroy, podium, alegre, gower, racquetball,
# Nearest to frequency: styling, time”, shekhar, 165, comune, 8500, sie, noire,
# Nearest to injury: lacks, climbs, whimsical, gcse, melodrama, transylvanian, cornerstone, sdp,
# Nearest to register: compensation, ei, cc, firebox, slid, sinners, frente, invalidated,
# Nearest to little: sweetened, damato, storyline, vitesse, 306%, fittings, 1102, “for,
# Nearest to shakespeares: scrambling, primitives, wheel, gauges, coxswain, dissociation, proceeds, overdue,
# Nearest to irwin: corazon, pyrite, tallest, sprung, kwh, redesign, ste, atman,
# Nearest to invading: peoples, attainment, stenosis, whistler, mallory, williamstown, raffaele, lapland,
# Nearest to 99%: sar, lombardi, lacks, bistro, aphids, ascot, paulista, brest,
# Nearest to protector: chernivtsi, slovak, sacral, ppv, lungs, 69%, schreiber, handwriting,
# Nearest to reginald: crore, bra, spurious, bernice, songwriting, spooky, almanac, depose,
# Nearest to polished: cricketers, fisa, psionic, 99%, rodez, gondor, palpi, 389,
# Nearest to amplitude: clergyman, solitude, lessen, yeh, bullies, ars, jess, 778,
# Epoch 1/20 Iteration: 5100 Avg. Training loss: 0.4510 0.4408 sec/batch
# Epoch 1/20 Iteration: 5200 Avg. Training loss: 0.4721 0.4212 sec/batch
# Epoch 1/20 Iteration: 5300 Avg. Training loss: 0.4393 0.4088 sec/batch
# Epoch 1/20 Iteration: 5400 Avg. Training loss: 0.4559 0.4546 sec/batch
# Epoch 1/20 Iteration: 5500 Avg. Training loss: 0.4519 0.4544 sec/batch
# Epoch 1/20 Iteration: 5600 Avg. Training loss: 0.4960 0.4356 sec/batch
# Epoch 1/20 Iteration: 5700 Avg. Training loss: 0.4610 0.4274 sec/batch
# Epoch 1/20 Iteration: 5800 Avg. Training loss: 0.4476 0.4405 sec/batch
# Epoch 1/20 Iteration: 5900 Avg. Training loss: 0.4653 0.4149 sec/batch
# Epoch 1/20 Iteration: 6000 Avg. Training loss: 0.4357 0.4120 sec/batch
# Nearest to 1906: trackers, ontology, aperture, yorker, splendid, llm, rong, shouting,
# Nearest to worth: classifies, miner, medically, precisely, straps, weep, kumari, insensitive,
# Nearest to category: sentence, rbis, 1310, 1515, carly, warmed, wrangler, ulcer,
# Nearest to whilst: partridge, llm, podium, alegre, durbin, gilroy, gower, ars,
# Nearest to frequency: styling, time”, shekhar, 8500, 165, gibbons, renovation, noire,
# Nearest to injury: lacks, climbs, gcse, melodrama, whimsical, cornerstone, zoological, sdp,
# Nearest to register: frente, firebox, ei, compensation, invalidated, slid, sinners, runic,
# Nearest to little: sweetened, damato, storyline, 306%, vitesse, “for, fittings, dorchester,
# Nearest to shakespeares: scrambling, primitives, wheel, dissociation, coxswain, overdue, proceeds, gauges,
# Nearest to irwin: corazon, pyrite, kwh, redesign, tallest, sprung, atman, ste,
# Nearest to invading: peoples, mallory, stenosis, attainment, whistler, lapland, williamstown, blocking,
# Nearest to 99%: sar, lacks, lombardi, paulista, aphids, sheets, brave, bistro,
# Nearest to protector: chernivtsi, slovak, lungs, sacral, handwriting, ppv, 69%, schreiber,
# Nearest to reginald: crore, bra, spurious, songwriting, bernice, spooky, equalled, tolstoy,
# Nearest to polished: cricketers, fisa, psionic, rumor, gondor, 99%, chola, nakhon,
# Nearest to amplitude: clergyman, bullies, solitude, yeh, lessen, jess, ars, 778,
# Epoch 1/20 Iteration: 6100 Avg. Training loss: 0.4699 0.4039 sec/batch
# Epoch 1/20 Iteration: 6200 Avg. Training loss: 0.4610 0.3840 sec/batch
# Epoch 1/20 Iteration: 6300 Avg. Training loss: 0.4671 0.3792 sec/batch
# Epoch 1/20 Iteration: 6400 Avg. Training loss: 0.4480 0.3696 sec/batch
# Epoch 1/20 Iteration: 6500 Avg. Training loss: 0.5006 0.3646 sec/batch
# Epoch 1/20 Iteration: 6600 Avg. Training loss: 0.4627 0.3804 sec/batch
# Epoch 1/20 Iteration: 6700 Avg. Training loss: 0.4631 0.3816 sec/batch
# Epoch 1/20 Iteration: 6800 Avg. Training loss: 0.4655 0.4046 sec/batch
# Epoch 1/20 Iteration: 6900 Avg. Training loss: 0.4976 0.3780 sec/batch
# Epoch 1/20 Iteration: 7000 Avg. Training loss: 0.4968 0.3724 sec/batch
# Nearest to 1906: trackers, ontology, yorker, aperture, llm, rong, splendid, cristobal,
# Nearest to worth: classifies, miner, medically, precisely, kumari, weep, straps, yume,
# Nearest to category: 1310, sentence, rbis, 1515, wrangler, carly, warmed, earthenware,
# Nearest to whilst: partridge, llm, gilroy, podium, alegre, durbin, 1634, racquetball,
# Nearest to frequency: styling, time”, shekhar, 8500, 165, gibbons, fundraisers, renovation,
# Nearest to injury: lacks, climbs, gcse, paternity, melodrama, cornerstone, automakers, transylvanian,
# Nearest to register: ei, firebox, frente, compensation, sinners, slid, tremendously, invalidated,
# Nearest to little: sweetened, damato, storyline, fittings, 306%, dorchester, autry, “for,
# Nearest to shakespeares: scrambling, primitives, wheel, gauges, dissociation, coxswain, proceeds, svenska,
# Nearest to irwin: corazon, pyrite, kwh, redesign, tallest, sprung, atman, materiel,
# Nearest to invading: peoples, mallory, stenosis, whistler, lapland, blocking, williamstown, swansea,
# Nearest to 99%: sar, lacks, sheets, brave, aphids, lombardi, paulista, bistro,
# Nearest to protector: chernivtsi, ppv, handwriting, lungs, 69%, sacral, ramsay, schreiber,
# Nearest to reginald: bra, crore, spurious, bernice, songwriting, spooky, almanac, equalled,
# Nearest to polished: cricketers, fisa, psionic, chola, rumor, nakhon, palpi, gondor,
# Nearest to amplitude: clergyman, solitude, lessen, bullies, yeh, jess, ars, 778,
# Epoch 1/20 Iteration: 7100 Avg. Training loss: 0.4763 0.4040 sec/batch
# Epoch 1/20 Iteration: 7200 Avg. Training loss: 0.4877 0.3718 sec/batch
# Epoch 1/20 Iteration: 7300 Avg. Training loss: 0.4536 0.3775 sec/batch
# Epoch 1/20 Iteration: 7400 Avg. Training loss: 0.4849 0.3629 sec/batch
# Epoch 1/20 Iteration: 7500 Avg. Training loss: 0.4401 0.3852 sec/batch
# Epoch 1/20 Iteration: 7600 Avg. Training loss: 0.4652 0.3893 sec/batch
# Epoch 1/20 Iteration: 7700 Avg. Training loss: 0.4521 0.3981 sec/batch
# Epoch 1/20 Iteration: 7800 Avg. Training loss: 0.4934 0.3663 sec/batch
# Epoch 1/20 Iteration: 7900 Avg. Training loss: 0.4809 0.3638 sec/batch
# Epoch 1/20 Iteration: 8000 Avg. Training loss: 0.4731 0.3524 sec/batch
# Nearest to 1906: trackers, ontology, yorker, llm, aperture, splendid, rong, underworld,
# Nearest to worth: classifies, miner, medically, precisely, weep, straps, kumari, orientalism,
# Nearest to category: 1310, sentence, rbis, 1515, earthenware, wrangler, simulations, ulcer,
# Nearest to whilst: partridge, alegre, llm, podium, durbin, gilroy, mugabe, gower,
# Nearest to frequency: styling, time”, shekhar, 8500, gibbons, 165, fundraisers, reservists,
# Nearest to injury: lacks, climbs, paternity, cornerstone, melodrama, gcse, nws, reruns,
# Nearest to register: ei, frente, firebox, tremendously, runic, gamers, slid, compensation,
# Nearest to little: sweetened, damato, storyline, dorchester, fittings, 306%, “for, autry,
# Nearest to shakespeares: scrambling, primitives, gauges, wheel, coxswain, svenska, proceeds, dissociation,
# Nearest to irwin: pyrite, corazon, tallest, kwh, redesign, atman, materiel, sprung,
# Nearest to invading: peoples, mallory, stenosis, lapland, blocking, survival, swansea, whistler,
# Nearest to 99%: sar, lacks, brave, paulista, sheets, aphids, lombardi, polished,
# Nearest to protector: chernivtsi, ppv, handwriting, schreiber, sacral, lungs, ramsay, baths,
# Nearest to reginald: bra, crore, spurious, songwriting, spooky, bernice, almanac, equalled,
# Nearest to polished: cricketers, chola, fisa, rumor, nakhon, psionic, 99%, seldom,
# Nearest to amplitude: clergyman, solitude, lessen, bullies, yeh, jess, 778, ars,
# Epoch 1/20 Iteration: 8100 Avg. Training loss: 0.4744 0.3326 sec/batch
# Epoch 1/20 Iteration: 8200 Avg. Training loss: 0.4598 0.5286 sec/batch
# Epoch 1/20 Iteration: 8300 Avg. Training loss: 0.4897 0.4991 sec/batch
# Epoch 1/20 Iteration: 8400 Avg. Training loss: 0.4773 0.4412 sec/batch
# Epoch 1/20 Iteration: 8500 Avg. Training loss: 0.4187 0.4967 sec/batch
# Epoch 1/20 Iteration: 8600 Avg. Training loss: 0.4322 0.5063 sec/batch
# Epoch 1/20 Iteration: 8700 Avg. Training loss: 0.4666 0.5007 sec/batch
# Epoch 1/20 Iteration: 8800 Avg. Training loss: 0.4657 0.4436 sec/batch
# Epoch 1/20 Iteration: 8900 Avg. Training loss: 0.4764 0.4858 sec/batch
# Epoch 1/20 Iteration: 9000 Avg. Training loss: 0.4969 0.4877 sec/batch
# Nearest to 1906: trackers, ontology, yorker, llm, rong, aperture, splendid, underworld,
# Nearest to worth: classifies, miner, medically, straps, precisely, weep, territorys, vas,
# Nearest to category: 1310, sentence, rbis, 1515, earthenware, wrangler, simulations, strathmore,
# Nearest to whilst: partridge, alegre, llm, durbin, podium, gilroy, mugabe, femme,
# Nearest to frequency: styling, time”, shekhar, 8500, 165, fundraisers, gibbons, renovation,
# Nearest to injury: lacks, paternity, climbs, cornerstone, rescinded, melodrama, reruns, gcse,
# Nearest to register: ei, frente, invalidated, gamers, runic, sinners, firebox, tremendously,
# Nearest to little: sweetened, damato, storyline, dorchester, fittings, 306%, eyes, prion,
# Nearest to shakespeares: scrambling, primitives, gauges, svenska, coxswain, proceeds, wheel, dissociation,
# Nearest to irwin: corazon, pyrite, kwh, tallest, redesign, materiel, camilla, atman,
# Nearest to invading: peoples, mallory, stenosis, swansea, blocking, survival, lapland, forces,
# Nearest to 99%: sar, lacks, sheets, brave, aphids, polished, paulista, brest,
# Nearest to protector: chernivtsi, ppv, schreiber, lungs, sacral, 69%, handwriting, slovak,
# Nearest to reginald: crore, bra, songwriting, spurious, equalled, bernice, almanac, tolstoy,
# Nearest to polished: fisa, cricketers, chola, nakhon, rumor, 99%, psionic, seldom,
# Nearest to amplitude: clergyman, solitude, lessen, yeh, bullies, ars, 778, jess,
# Epoch 1/20 Iteration: 9100 Avg. Training loss: 0.4510 0.4120 sec/batch
# Epoch 1/20 Iteration: 9200 Avg. Training loss: 0.4686 0.4574 sec/batch
# Epoch 1/20 Iteration: 9300 Avg. Training loss: 0.4624 0.5089 sec/batch
# Epoch 1/20 Iteration: 9400 Avg. Training loss: 0.4863 0.4985 sec/batch
# Epoch 1/20 Iteration: 9500 Avg. Training loss: 0.4582 0.4879 sec/batch
# Epoch 1/20 Iteration: 9600 Avg. Training loss: 0.4958 0.5027 sec/batch
# Epoch 1/20 Iteration: 9700 Avg. Training loss: 0.4773 0.4668 sec/batch
# Epoch 1/20 Iteration: 9800 Avg. Training loss: 0.4719 0.4703 sec/batch
# Epoch 1/20 Iteration: 9900 Avg. Training loss: 0.4650 0.4272 sec/batch
# Epoch 1/20 Iteration: 10000 Avg. Training loss: 0.4451 0.4407 sec/batch
# Nearest to 1906: trackers, ontology, yorker, llm, aperture, underworld, splendid, machinist,
# Nearest to worth: classifies, miner, medically, straps, territorys, precisely, romanticism, orientalism,
# Nearest to category: 1310, sentence, rbis, earthenware, wrangler, warmed, 1515, lantern,
# Nearest to whilst: partridge, llm, alegre, singapores, mugabe, podium, durbin, gilroy,
# Nearest to frequency: styling, time”, 8500, shekhar, 165, renovation, fundraisers, reservists,
# Nearest to injury: lacks, climbs, paternity, reruns, rescinded, cornerstone, melodrama, morales,
# Nearest to register: ei, invalidated, frente, runic, gamers, deputation, tremendously, firebox,
# Nearest to little: damato, sweetened, dorchester, storyline, eyes, fittings, prion, 306%,
# Nearest to shakespeares: scrambling, primitives, coxswain, gauges, wheel, svenska, proceeds, dissociation,
# Nearest to irwin: corazon, kwh, pyrite, redesign, tallest, atman, phobia, mulligan,
# Nearest to invading: peoples, mallory, blocking, survival, forces, stenosis, lapland, whistler,
# Nearest to 99%: sar, lacks, polished, brave, aphids, sheets, paulista, fortnight,
# Nearest to protector: chernivtsi, ppv, sacral, governess, impressive, schreiber, lungs, barking,
# Nearest to reginald: bra, crore, spurious, songwriting, bernice, equalled, almanac, spooky,
# Nearest to polished: fisa, 99%, chola, rumor, cricketers, nakhon, seldom, 1782,
# Nearest to amplitude: clergyman, solitude, lessen, yeh, bullies, ars, jess, utica,
# Epoch 1/20 Iteration: 10100 Avg. Training loss: 0.4783 0.4463 sec/batch
# Epoch 1/20 Iteration: 10200 Avg. Training loss: 0.4605 0.4580 sec/batch
# Epoch 1/20 Iteration: 10300 Avg. Training loss: 0.4664 0.4387 sec/batch
# Epoch 1/20 Iteration: 10400 Avg. Training loss: 0.4483 0.4077 sec/batch
# Epoch 1/20 Iteration: 10500 Avg. Training loss: 0.4638 0.4585 sec/batch
# Epoch 1/20 Iteration: 10600 Avg. Training loss: 0.4721 0.4438 sec/batch
# Epoch 1/20 Iteration: 10700 Avg. Training loss: 0.4423 0.4448 sec/batch
# Epoch 1/20 Iteration: 10800 Avg. Training loss: 0.4837 0.4671 sec/batch
# Epoch 1/20 Iteration: 10900 Avg. Training loss: 0.4624 0.4607 sec/batch
# Epoch 1/20 Iteration: 11000 Avg. Training loss: 0.4670 0.5127 sec/batch
# Nearest to 1906: trackers, ontology, yorker, llm, aperture, underworld, 1623, cristobal,
# Nearest to worth: classifies, miner, straps, medically, precisely, weep, territorys, romanticism,
# Nearest to category: 1310, rbis, sentence, earthenware, 1515, warmed, wrangler, kg,
# Nearest to whilst: partridge, llm, alegre, podium, mugabe, singapores, durbin, gilroy,
# Nearest to frequency: styling, time”, 8500, shekhar, 165, fundraisers, reservists, maier,
# Nearest to injury: lacks, paternity, climbs, reruns, automakers, fever, cornerstone, rescinded,
# Nearest to register: ei, invalidated, deputation, runic, frente, tremendously, gamers, firebox,
# Nearest to little: damato, dorchester, sweetened, storyline, eyes, 306%, ineffective, hairdresser,
# Nearest to shakespeares: scrambling, primitives, gauges, coxswain, proceeds, wheel, svenska, rhyming,
# Nearest to irwin: corazon, redesign, tallest, pyrite, atman, kwh, camilla, phobia,
# Nearest to invading: peoples, mallory, forces, survival, blocking, lapland, whistler, stenosis,
# Nearest to 99%: sar, lacks, polished, aphids, brave, rer, brest, sheets,
# Nearest to protector: chernivtsi, ppv, impressive, governess, sacral, lungs, barking, schreiber,
# Nearest to reginald: crore, bra, spurious, songwriting, aggressiveness, tolstoy, bernice, 001%,
# Nearest to polished: fisa, chola, 99%, nakhon, cricketers, shining, rumor, 1782,
# Nearest to amplitude: clergyman, lessen, solitude, yeh, bullies, ars, jess, utica,
# Epoch 1/20 Iteration: 11100 Avg. Training loss: 0.4557 0.4283 sec/batch
# Epoch 1/20 Iteration: 11200 Avg. Training loss: 0.4560 0.3820 sec/batch
# Epoch 1/20 Iteration: 11300 Avg. Training loss: 0.4676 0.4542 sec/batch
# Epoch 1/20 Iteration: 11400 Avg. Training loss: 0.4790 0.4192 sec/batch
# Epoch 1/20 Iteration: 11500 Avg. Training loss: 0.4599 0.4203 sec/batch
# Epoch 1/20 Iteration: 11600 Avg. Training loss: 0.4589 0.4260 sec/batch
# Epoch 1/20 Iteration: 11700 Avg. Training loss: 0.4678 0.4340 sec/batch
# Epoch 1/20 Iteration: 11800 Avg. Training loss: 0.5050 0.3950 sec/batch
# Epoch 1/20 Iteration: 11900 Avg. Training loss: 0.4433 0.3830 sec/batch
# Epoch 1/20 Iteration: 12000 Avg. Training loss: 0.4505 0.4036 sec/batch
# Nearest to 1906: trackers, ontology, yorker, aperture, llm, underworld, brickyard, 025,
# Nearest to worth: classifies, miner, medically, straps, weep, territorys, precisely, orientalism,
# Nearest to category: 1310, sentence, rbis, earthenware, warmed, wrangler, 1515, ulcer,
# Nearest to whilst: partridge, llm, alegre, durbin, 1634, podium, gilroy, mugabe,
# Nearest to frequency: styling, time”, shekhar, reservists, 8500, 165, maier, detecting,
# Nearest to injury: lacks, paternity, climbs, reruns, fever, cornerstone, automakers, rescinded,
# Nearest to register: ei, invalidated, deputation, gamers, firebox, runic, slid, frente,
# Nearest to little: eyes, damato, sweetened, dorchester, storyline, ineffective, autry, jacket,
# Nearest to shakespeares: scrambling, primitives, coxswain, gauges, proceeds, svenska, wheel, kaliningrad,
# Nearest to irwin: corazon, redesign, atman, pyrite, kwh, tallest, camilla, ste,
# Nearest to invading: peoples, mallory, forces, survival, chadian, lapland, rhinos, republics,
# Nearest to 99%: sar, polished, lacks, aphids, brave, brest, fortnight, paulista,
# Nearest to protector: chernivtsi, impressive, ppv, barking, 69%, governess, handwriting, sacral,
# Nearest to reginald: crore, bra, spurious, songwriting, tolstoy, algernon, realises, equalled,
# Nearest to polished: 99%, fisa, chola, shining, cricketers, seldom, nakhon, rumor,
# Nearest to amplitude: clergyman, solitude, lessen, yeh, bullies, utica, ars, jess,
# Epoch 1/20 Iteration: 12100 Avg. Training loss: 0.4770 0.4061 sec/batch
# Epoch 1/20 Iteration: 12200 Avg. Training loss: 0.4470 0.3903 sec/batch
# Epoch 1/20 Iteration: 12300 Avg. Training loss: 0.4576 0.4173 sec/batch
# Epoch 1/20 Iteration: 12400 Avg. Training loss: 0.4663 0.4218 sec/batch
# Epoch 1/20 Iteration: 12500 Avg. Training loss: 0.4335 0.3973 sec/batch
# Epoch 1/20 Iteration: 12600 Avg. Training loss: 0.4917 0.4517 sec/batch
# Epoch 1/20 Iteration: 12700 Avg. Training loss: 0.4582 0.5146 sec/batch
# Epoch 1/20 Iteration: 12800 Avg. Training loss: 0.4668 0.4417 sec/batch
# Epoch 1/20 Iteration: 12900 Avg. Training loss: 0.4362 0.4626 sec/batch
# Epoch 1/20 Iteration: 13000 Avg. Training loss: 0.4629 0.4621 sec/batch
# Nearest to 1906: trackers, ontology, yorker, llm, doncaster, underworld, aperture, hydrological,
# Nearest to worth: classifies, miner, medically, territorys, romanticism, straps, weep, precisely,
# Nearest to category: 1310, sentence, 1515, earthenware, rbis, wrangler, warmed, motile,
# Nearest to whilst: partridge, llm, alegre, podium, durbin, mugabe, gower, javelin,
# Nearest to frequency: styling, time”, shekhar, reservists, maier, variable, detecting, renovation,
# Nearest to injury: lacks, paternity, reruns, fever, climbs, melodrama, against, automakers,
# Nearest to register: ei, invalidated, runic, bisexuality, deputation, faris, slid, firebox,
# Nearest to little: sweetened, damato, storyline, eyes, dorchester, ineffective, autry, jacket,
# Nearest to shakespeares: scrambling, primitives, coxswain, proceeds, gauges, kaliningrad, terrific, svenska,
# Nearest to irwin: redesign, corazon, atman, kwh, pyrite, ste, phobia, tallest,
# Nearest to invading: peoples, forces, mallory, survival, lapland, chadian, swansea, republics,
# Nearest to 99%: sar, lacks, polished, brave, aphids, brest, nunavut, fortnight,
# Nearest to protector: chernivtsi, ppv, barking, impressive, 69%, handwriting, sacral, governess,
# Nearest to reginald: crore, spurious, bra, songwriting, realises, equalled, aggressiveness, depose,
# Nearest to polished: fisa, cricketers, chola, nakhon, rumor, 99%, shining, psionic,
# Nearest to amplitude: clergyman, solitude, lessen, utica, bullies, yeh, jess, 778,
# Epoch 1/20 Iteration: 13100 Avg. Training loss: 0.4740 0.4339 sec/batch
# Epoch 1/20 Iteration: 13200 Avg. Training loss: 0.4370 0.4446 sec/batch
# Epoch 1/20 Iteration: 13300 Avg. Training loss: 0.4389 0.4129 sec/batch
# Epoch 1/20 Iteration: 13400 Avg. Training loss: 0.4448 0.4403 sec/batch
# Epoch 1/20 Iteration: 13500 Avg. Training loss: 0.4647 0.3778 sec/batch
# Epoch 1/20 Iteration: 13600 Avg. Training loss: 0.4554 0.4382 sec/batch
# Epoch 1/20 Iteration: 13700 Avg. Training loss: 0.4741 0.4794 sec/batch
# Epoch 1/20 Iteration: 13800 Avg. Training loss: 0.4908 0.4960 sec/batch
# Epoch 1/20 Iteration: 13900 Avg. Training loss: 0.4813 0.4625 sec/batch
# Epoch 1/20 Iteration: 14000 Avg. Training loss: 0.4399 0.4765 sec/batch
# Nearest to 1906: trackers, ontology, yorker, llm, underworld, doncaster, 1623, hydrological,
# Nearest to worth: classifies, miner, medically, territorys, romanticism, weep, straps, orientalism,
# Nearest to category: 1310, 1515, sentence, earthenware, wrangler, warmed, kg, rbis,
# Nearest to whilst: partridge, llm, alegre, durbin, javelin, podium, gilroy, gower,
# Nearest to frequency: styling, time”, variable, shekhar, reservists, detecting, maier, renovation,
# Nearest to injury: lacks, paternity, fever, reruns, against, climbs, conspired, melodrama,
# Nearest to register: ei, runic, belknap, slid, faris, ophthalmic, deputation, gamers,
# Nearest to little: sweetened, eyes, dorchester, storyline, damato, jacket, autry, ineffective,
# Nearest to shakespeares: scrambling, primitives, coxswain, kaliningrad, gauges, svenska, proceeds, sextet,
# Nearest to irwin: corazon, redesign, kwh, phobia, pyrite, atman, ste, tallest,
# Nearest to invading: peoples, forces, mallory, survival, blocking, attacking, chadian, lapland,
# Nearest to 99%: sar, lacks, brest, polished, aphids, brave, rer, fortnight,
# Nearest to protector: chernivtsi, ppv, barking, 69%, sacral, impressive, handwriting, governess,
# Nearest to reginald: crore, spurious, bra, realises, equalled, songwriting, algernon, almanac,
# Nearest to polished: fisa, cricketers, nakhon, chola, 99%, bartolomé, shining, rumor,
# Nearest to amplitude: clergyman, solitude, lessen, utica, yeh, bullies, jess, burners,
# Epoch 1/20 Iteration: 14100 Avg. Training loss: 0.4558 0.4300 sec/batch
# Epoch 1/20 Iteration: 14200 Avg. Training loss: 0.4548 0.4102 sec/batch
# Epoch 1/20 Iteration: 14300 Avg. Training loss: 0.4762 0.4712 sec/batch
# Epoch 1/20 Iteration: 14400 Avg. Training loss: 0.4416 0.4424 sec/batch
# Epoch 1/20 Iteration: 14500 Avg. Training loss: 0.4362 0.4205 sec/batch
# Epoch 1/20 Iteration: 14600 Avg. Training loss: 0.4225 0.4378 sec/batch
# Epoch 1/20 Iteration: 14700 Avg. Training loss: 0.4543 0.4409 sec/batch
# Epoch 1/20 Iteration: 14800 Avg. Training loss: 0.4720 0.4202 sec/batch
# Epoch 1/20 Iteration: 14900 Avg. Training loss: 0.4665 0.4499 sec/batch
# Epoch 1/20 Iteration: 15000 Avg. Training loss: 0.4702 0.4724 sec/batch
# Nearest to 1906: trackers, yorker, ontology, doncaster, underworld, llm, 1623, brickyard,
# Nearest to worth: classifies, miner, territorys, medically, romanticism, weep, cognac, straps,
# Nearest to category: 1310, wrangler, ulcer, sentence, 1515, rbis, earthenware, kg,
# Nearest to whilst: partridge, llm, alegre, javelin, durbin, gower, podium, gilroy,
# Nearest to frequency: styling, time”, variable, detecting, reservists, shekhar, futility, maier,
# Nearest to injury: lacks, paternity, fever, reruns, against, melodrama, conspired, climbs,
# Nearest to register: ei, runic, slid, faris, bisexuality, belknap, lungs, deputation,
# Nearest to little: sweetened, eyes, storyline, dorchester, damato, jacket, prion, masks,
# Nearest to shakespeares: scrambling, primitives, coxswain, kaliningrad, gauges, svenska, sakai, rhyming,
# Nearest to irwin: corazon, redesign, kwh, ste, phobia, pyrite, atman, camilla,
# Nearest to invading: peoples, forces, survival, mallory, blocking, chadian, attacking, swansea,
# Nearest to 99%: sar, brest, aphids, rer, polished, lacks, nonsensical, nunavut,
# Nearest to protector: chernivtsi, ppv, 69%, impressive, sacral, moseley, governess, handwriting,
# Nearest to reginald: spurious, crore, realises, bra, aggressiveness, songwriting, equalled, algernon,
# Nearest to polished: fisa, rumor, nakhon, shining, chola, 99%, cricketers, seldom,
# Nearest to amplitude: clergyman, solitude, lessen, utica, yeh, bullies, burners, jess,
# Epoch 1/20 Iteration: 15100 Avg. Training loss: 0.4507 0.4418 sec/batch
# Epoch 1/20 Iteration: 15200 Avg. Training loss: 0.4519 0.4663 sec/batch
# Epoch 1/20 Iteration: 15300 Avg. Training loss: 0.4463 0.4756 sec/batch
# Epoch 1/20 Iteration: 15400 Avg. Training loss: 0.4830 0.4245 sec/batch
# Epoch 1/20 Iteration: 15500 Avg. Training loss: 0.4618 0.4699 sec/batch
# Epoch 1/20 Iteration: 15600 Avg. Training loss: 0.4726 0.4737 sec/batch
# Epoch 1/20 Iteration: 15700 Avg. Training loss: 0.4393 0.4515 sec/batch
# Epoch 1/20 Iteration: 15800 Avg. Training loss: 0.4757 0.4768 sec/batch
# Epoch 1/20 Iteration: 15900 Avg. Training loss: 0.4808 0.4417 sec/batch
# Epoch 1/20 Iteration: 16000 Avg. Training loss: 0.4711 0.4682 sec/batch
# Nearest to 1906: trackers, yorker, ontology, doncaster, underworld, llm, 1623, registries,
# Nearest to worth: classifies, miner, territorys, medically, romanticism, vas, orientalism, rescinded,
# Nearest to category: 1310, wrangler, ulcer, earthenware, kg, 1515, wheel, sentence,
# Nearest to whilst: partridge, llm, alegre, durbin, javelin, gower, unproductive, singapores,
# Nearest to frequency: styling, variable, time”, detecting, shekhar, reservists, cyclic, futility,
# Nearest to injury: lacks, paternity, against, fever, reruns, conspired, melodrama, rescinded,
# Nearest to register: ei, runic, faris, bisexuality, slid, ophthalmic, deputation, belknap,
# Nearest to little: eyes, storyline, sweetened, damato, dorchester, motionless, jacket, prion,
# Nearest to shakespeares: scrambling, primitives, kaliningrad, gauges, rhyming, svenska, coxswain, terrific,
# Nearest to irwin: corazon, redesign, ste, kwh, phobia, pyrite, schenectady, atman,
# Nearest to invading: peoples, forces, survival, mallory, attacking, blocking, swansea, chadian,
# Nearest to 99%: sar, aphids, brest, nunavut, polished, nonsensical, lombardi, rer,
# Nearest to protector: chernivtsi, ppv, 69%, barking, sacral, impressive, castleton, ramsay,
# Nearest to reginald: crore, spurious, realises, bra, algernon, songwriting, equalled, aggressiveness,
# Nearest to polished: fisa, shining, seldom, cricketers, 99%, nakhon, supermodel, rumor,
# Nearest to amplitude: lessen, solitude, clergyman, utica, yeh, bullies, burners, jess,
# Epoch 1/20 Iteration: 16100 Avg. Training loss: 0.4437 0.4167 sec/batch
# Epoch 1/20 Iteration: 16200 Avg. Training loss: 0.4686 0.4296 sec/batch
# Epoch 1/20 Iteration: 16300 Avg. Training loss: 0.4399 0.4139 sec/batch
# Epoch 1/20 Iteration: 16400 Avg. Training loss: 0.4413 0.4420 sec/batch
# Epoch 1/20 Iteration: 16500 Avg. Training loss: 0.4419 0.4046 sec/batch
# Epoch 1/20 Iteration: 16600 Avg. Training loss: 0.4658 0.4114 sec/batch
# Epoch 1/20 Iteration: 16700 Avg. Training loss: 0.4683 0.5661 sec/batch
# Epoch 1/20 Iteration: 16800 Avg. Training loss: 0.4778 0.4601 sec/batch
# Epoch 1/20 Iteration: 16900 Avg. Training loss: 0.4855 0.4255 sec/batch
# Epoch 1/20 Iteration: 17000 Avg. Training loss: 0.4545 0.4395 sec/batch
# Nearest to 1906: trackers, yorker, ontology, doncaster, llm, registries, 1623, underworld,
# Nearest to worth: classifies, miner, territorys, romanticism, medically, weep, rescinded, orientalism,
# Nearest to category: 1310, wrangler, ulcer, earthenware, wheel, kg, 1515, sentence,
# Nearest to whilst: partridge, llm, alegre, javelin, gower, aso, mugabe, unproductive,
# Nearest to frequency: styling, variable, detecting, time”, relative, cyclic, shekhar, futility,
# Nearest to injury: lacks, against, paternity, fever, reruns, conspired, rescinded, melodrama,
# Nearest to register: runic, ei, bisexuality, ophthalmic, faris, slid, deputation, belknap,
# Nearest to little: eyes, sweetened, storyline, damato, motionless, ineffective, dorchester, scallop,
# Nearest to shakespeares: scrambling, primitives, kaliningrad, coxswain, gauges, svenska, sextet, rhyming,
# Nearest to irwin: corazon, redesign, kwh, phobia, pyrite, ste, schenectady, pinot,
# Nearest to invading: peoples, forces, survival, mallory, blocking, attacking, swansea, chadian,
# Nearest to 99%: sar, nunavut, aphids, nonsensical, auld, lombardi, polished, brest,
# Nearest to protector: chernivtsi, ppv, barking, sacral, ravel, impressive, castleton, handwriting,
# Nearest to reginald: crore, spurious, realises, bra, aggressiveness, algernon, equalled, songwriting,
# Nearest to polished: shining, fisa, supermodel, seldom, cricketers, rumor, nakhon, seasonal,
# Nearest to amplitude: lessen, solitude, clergyman, yeh, utica, jess, burners, bullies,
# Epoch 1/20 Iteration: 17100 Avg. Training loss: 0.4673 0.5000 sec/batch
# Epoch 1/20 Iteration: 17200 Avg. Training loss: 0.4719 0.4516 sec/batch
# Epoch 1/20 Iteration: 17300 Avg. Training loss: 0.4623 0.4657 sec/batch
# Epoch 1/20 Iteration: 17400 Avg. Training loss: 0.4449 0.4407 sec/batch
# Epoch 1/20 Iteration: 17500 Avg. Training loss: 0.4288 0.4339 sec/batch
# Epoch 1/20 Iteration: 17600 Avg. Training loss: 0.4206 0.3879 sec/batch
# Epoch 1/20 Iteration: 17700 Avg. Training loss: 0.4609 0.4272 sec/batch
# Epoch 1/20 Iteration: 17800 Avg. Training loss: 0.4510 0.4212 sec/batch
# Epoch 1/20 Iteration: 17900 Avg. Training loss: 0.4761 0.4256 sec/batch
# Epoch 1/20 Iteration: 18000 Avg. Training loss: 0.4513 0.4701 sec/batch
# Nearest to 1906: trackers, yorker, doncaster, ontology, llm, 1396, louisa, 1623,
# Nearest to worth: classifies, miner, territorys, romanticism, medically, weep, rescinded, taxicab,
# Nearest to category: 1310, wrangler, kg, 1515, wheel, ulcer, sentence, rbis,
# Nearest to whilst: partridge, llm, alegre, javelin, gower, aso, mugabe, singapores,
# Nearest to frequency: styling, variable, detecting, time”, cyclic, relative, wavelengths, futility,
# Nearest to injury: against, lacks, paternity, fever, rescinded, conspired, reruns, nws,
# Nearest to register: bisexuality, runic, ophthalmic, ei, slid, faris, starrs, deputation,
# Nearest to little: eyes, storyline, sweetened, damato, motionless, autry, dorchester, ineffective,
# Nearest to shakespeares: scrambling, primitives, kaliningrad, coxswain, terrific, rhyming, svenska, gauges,
# Nearest to irwin: corazon, kwh, redesign, phobia, ste, pyrite, schenectady, pinot,
# Nearest to invading: peoples, forces, survival, mallory, blocking, attacking, swansea, chadian,
# Nearest to 99%: sar, nunavut, nonsensical, aphids, brest, lombardi, rer, reveal,
# Nearest to protector: chernivtsi, ppv, barking, impressive, castleton, forgeries, sacral, ravel,
# Nearest to reginald: crore, spurious, realises, bra, algernon, equalled, aggressiveness, songwriting,
# Nearest to polished: shining, fisa, supermodel, seldom, curves, cricketers, seasonal, nakhon,
# Nearest to amplitude: lessen, solitude, clergyman, utica, yeh, astonishing, burners, jess,
# Epoch 1/20 Iteration: 18100 Avg. Training loss: 0.4880 0.4263 sec/batch
# Epoch 1/20 Iteration: 18200 Avg. Training loss: 0.4451 0.4488 sec/batch
# Epoch 2/20 Iteration: 18300 Avg. Training loss: 0.4742 0.4467 sec/batch
# Epoch 2/20 Iteration: 18400 Avg. Training loss: 0.4528 0.4240 sec/batch
# Epoch 2/20 Iteration: 18500 Avg. Training loss: 0.4860 0.3853 sec/batch
# Epoch 2/20 Iteration: 18600 Avg. Training loss: 0.4452 0.3927 sec/batch
# Epoch 2/20 Iteration: 18700 Avg. Training loss: 0.4298 0.3954 sec/batch
# Epoch 2/20 Iteration: 18800 Avg. Training loss: 0.4643 0.4069 sec/batch
# Epoch 2/20 Iteration: 18900 Avg. Training loss: 0.4648 0.4262 sec/batch
# Epoch 2/20 Iteration: 19000 Avg. Training loss: 0.4610 0.3948 sec/batch
# Nearest to 1906: trackers, doncaster, yorker, llm, ontology, underworld, louisa, 1396,
# Nearest to worth: classifies, miner, territorys, romanticism, weep, understands, taxicab, medically,
# Nearest to category: 1310, wrangler, kg, 1515, wheel, warmed, rbis, motile,
# Nearest to whilst: partridge, llm, javelin, gower, 1634, aso, singapores, alegre,
# Nearest to frequency: variable, styling, cyclic, time”, relative, detecting, wavelengths, modulated,
# Nearest to injury: against, lacks, fever, paternity, rescinded, conspired, reruns, nws,
# Nearest to register: bisexuality, runic, ei, ophthalmic, slid, deputation, starrs, belknap,
# Nearest to little: eyes, storyline, damato, sweetened, motionless, autry, ineffective, scallop,
# Nearest to shakespeares: scrambling, primitives, kaliningrad, rhyming, coxswain, terrific, sakai, veolia,
# Nearest to irwin: corazon, phobia, kwh, redesign, ste, schenectady, pinot, geoff,
# Nearest to invading: peoples, forces, survival, mallory, attacking, blocking, swansea, chadian,
# Nearest to 99%: sar, nunavut, nonsensical, rer, brest, auld, aphids, paulista,
# Nearest to protector: chernivtsi, barking, ppv, castleton, forgeries, sacral, moseley, ramsay,
# Nearest to reginald: crore, realises, spurious, bra, algernon, equalled, aggressiveness, almanac,
# Nearest to polished: shining, curves, supermodel, seasonal, fisa, seldom, vinokourov, rumor,
# Nearest to amplitude: solitude, lessen, clergyman, utica, yeh, astonishing, yad, simple,
# Epoch 2/20 Iteration: 19100 Avg. Training loss: 0.4493 0.3817 sec/batch
# Epoch 2/20 Iteration: 19200 Avg. Training loss: 0.4523 0.3482 sec/batch
# Epoch 2/20 Iteration: 19300 Avg. Training loss: 0.4625 0.4123 sec/batch
# Epoch 2/20 Iteration: 19400 Avg. Training loss: 0.4559 0.3941 sec/batch
# Epoch 2/20 Iteration: 19500 Avg. Training loss: 0.4447 0.3536 sec/batch
# Epoch 2/20 Iteration: 19600 Avg. Training loss: 0.4409 0.3588 sec/batch
# Epoch 2/20 Iteration: 19700 Avg. Training loss: 0.4708 0.3676 sec/batch
# Epoch 2/20 Iteration: 19800 Avg. Training loss: 0.4334 0.3683 sec/batch
# Epoch 2/20 Iteration: 19900 Avg. Training loss: 0.4465 0.3559 sec/batch
# Epoch 2/20 Iteration: 20000 Avg. Training loss: 0.4447 0.3591 sec/batch
# Nearest to 1906: doncaster, trackers, yorker, llm, ontology, underworld, louisa, rwanda,
# Nearest to worth: classifies, miner, weep, territorys, baht, taxicab, medically, romanticism,
# Nearest to category: 1310, wrangler, kg, 1515, rbis, motile, wheel, earthenware,
# Nearest to whilst: partridge, llm, gower, aso, alegre, javelin, mugabe, 1634,
# Nearest to frequency: variable, styling, cyclic, relative, detecting, wavelengths, modulated, time”,
# Nearest to injury: lacks, against, paternity, fever, melodrama, rescinded, reruns, nws,
# Nearest to register: runic, bisexuality, ei, ophthalmic, slid, starrs, faris, deputation,
# Nearest to little: eyes, damato, storyline, motionless, sweetened, ineffective, prion, munnetra,
# Nearest to shakespeares: scrambling, primitives, kaliningrad, rhyming, sakai, sextet, georgian, coxswain,
# Nearest to irwin: kwh, phobia, corazon, ste, redesign, geoff, pinot, archdeacon,
# Nearest to invading: peoples, forces, survival, attacking, blocking, mallory, chadian, lapland,
# Nearest to 99%: sar, nunavut, nonsensical, rer, 53, brest, lombardi, auld,
# Nearest to protector: chernivtsi, barking, forgeries, ppv, moseley, sacral, castleton, civilisation,
# Nearest to reginald: crore, algernon, realises, spurious, bra, equalled, aggressiveness, edmonton,
# Nearest to polished: shining, curves, vinokourov, predefined, supermodel, seasonal, fisa, seldom,
# Nearest to amplitude: solitude, clergyman, yeh, lessen, utica, astonishing, implants, yad,
# Epoch 2/20 Iteration: 20100 Avg. Training loss: 0.4292 0.3734 sec/batch
# Epoch 2/20 Iteration: 20200 Avg. Training loss: 0.4372 0.3675 sec/batch
# Epoch 2/20 Iteration: 20300 Avg. Training loss: 0.4652 0.3482 sec/batch
# Epoch 2/20 Iteration: 20400 Avg. Training loss: 0.4511 0.4082 sec/batch
# Epoch 2/20 Iteration: 20500 Avg. Training loss: 0.4676 0.4321 sec/batch
# Epoch 2/20 Iteration: 20600 Avg. Training loss: 0.4954 0.3678 sec/batch
# Epoch 2/20 Iteration: 20700 Avg. Training loss: 0.4769 0.3509 sec/batch
# Epoch 2/20 Iteration: 20800 Avg. Training loss: 0.4977 0.3215 sec/batch
# Epoch 2/20 Iteration: 20900 Avg. Training loss: 0.4490 0.3178 sec/batch
# Epoch 2/20 Iteration: 21000 Avg. Training loss: 0.4331 0.3207 sec/batch
# Nearest to 1906: doncaster, yorker, trackers, llm, louisa, ontology, underworld, 1623,
# Nearest to worth: classifies, miner, weep, territorys, baht, cognac, urs, taxicab,
# Nearest to category: 1310, wrangler, kg, 1515, rbis, motile, wheel, warmed,
# Nearest to whilst: partridge, llm, alegre, gower, aso, 1634, javelin, mugabe,
# Nearest to frequency: variable, styling, cyclic, relative, modulated, wavelengths, detecting, recipes,
# Nearest to injury: lacks, against, fever, paternity, melodrama, rescinded, reruns, morales,
# Nearest to register: runic, bisexuality, ei, ophthalmic, slid, starrs, faris, lungs,
# Nearest to little: eyes, damato, storyline, sweetened, motionless, scallop, themed, ineffective,
# Nearest to shakespeares: scrambling, primitives, kaliningrad, rhyming, sextet, gauges, sakai, terrific,
# Nearest to irwin: kwh, phobia, corazon, ste, redesign, archdeacon, pinot, geoff,
# Nearest to invading: peoples, forces, survival, attacking, blocking, chadian, xvii, mallory,
# Nearest to 99%: sar, nunavut, nonsensical, 53, rer, brest, aphids, auld,
# Nearest to protector: chernivtsi, barking, forgeries, moseley, ppv, castleton, stuntman, ravel,
# Nearest to reginald: algernon, crore, spurious, realises, bra, aggressiveness, equalled, bride,
# Nearest to polished: shining, curves, predefined, seasonal, fisa, supermodel, vinokourov, seldom,
# Nearest to amplitude: solitude, utica, clergyman, astonishing, lessen, yeh, implants, yad,
# Epoch 2/20 Iteration: 21100 Avg. Training loss: 0.4707 0.3032 sec/batch
# Epoch 2/20 Iteration: 21200 Avg. Training loss: 0.4606 0.3021 sec/batch
# Epoch 2/20 Iteration: 21300 Avg. Training loss: 0.4480 0.3341 sec/batch
# Epoch 2/20 Iteration: 21400 Avg. Training loss: 0.4437 0.3164 sec/batch
# Epoch 2/20 Iteration: 21500 Avg. Training loss: 0.4478 0.3115 sec/batch
# Epoch 2/20 Iteration: 21600 Avg. Training loss: 0.4813 0.3233 sec/batch
# Epoch 2/20 Iteration: 21700 Avg. Training loss: 0.4536 0.3137 sec/batch
# Epoch 2/20 Iteration: 21800 Avg. Training loss: 0.4532 0.2972 sec/batch
# Epoch 2/20 Iteration: 21900 Avg. Training loss: 0.4589 0.3258 sec/batch
# Epoch 2/20 Iteration: 22000 Avg. Training loss: 0.4963 0.3069 sec/batch
# Nearest to 1906: doncaster, yorker, louisa, trackers, ontology, llm, underworld, brevard,
# Nearest to worth: classifies, miner, weep, baht, taxicab, territorys, cognac, curious,
# Nearest to category: 1310, kg, wrangler, 1515, rbis, wheel, motile, earthenware,
# Nearest to whilst: partridge, llm, alegre, aso, 1634, javelin, gower, podium,
# Nearest to frequency: variable, styling, cyclic, relative, modulated, wavelengths, amplitude, detecting,
# Nearest to injury: lacks, against, fever, paternity, melodrama, rescinded, reruns, cracking,
# Nearest to register: runic, ei, bisexuality, slid, lungs, deputation, ophthalmic, starrs,
# Nearest to little: eyes, storyline, damato, sweetened, motionless, scallop, themed, jacket,
# Nearest to shakespeares: scrambling, kaliningrad, primitives, terrific, rhyming, sextet, patronymic, sakai,
# Nearest to irwin: kwh, phobia, corazon, ste, redesign, archdeacon, geoff, pyrite,
# Nearest to invading: peoples, forces, survival, attacking, blocking, chadian, xvii, lapland,
# Nearest to 99%: sar, nunavut, 53, nonsensical, aphids, brest, rer, humboldt,
# Nearest to protector: chernivtsi, barking, castleton, forgeries, gwr, ravel, moseley, cricketers,
# Nearest to reginald: algernon, crore, spurious, realises, bra, equalled, housewife, aggressiveness,
# Nearest to polished: shining, curves, predefined, vinokourov, fisa, shaivism, seasonal, supermodel,
# Nearest to amplitude: astonishing, solitude, utica, frequency, clergyman, yeh, simple, yad,
# Epoch 2/20 Iteration: 22100 Avg. Training loss: 0.4677 0.3219 sec/batch
# Epoch 2/20 Iteration: 22200 Avg. Training loss: 0.4618 0.3069 sec/batch
# Epoch 2/20 Iteration: 22300 Avg. Training loss: 0.4756 0.3123 sec/batch
# Epoch 2/20 Iteration: 22400 Avg. Training loss: 0.4535 0.3138 sec/batch
# Epoch 2/20 Iteration: 22500 Avg. Training loss: 0.4403 0.3052 sec/batch
# ...
# Nearest to polished: richly, earthenware, phrasing, kimi, regalia, foreground, melancholic, [that],
# Nearest to amplitude: frequency, wave, formula_41, amplitudes, angular, modulated, formula_8, formula_34,
# Epoch 18/20 Iteration: 314100 Avg. Training loss: 0.5072 0.3228 sec/batch
# Epoch 18/20 Iteration: 314200 Avg. Training loss: 0.4858 0.3255 sec/batch
# Epoch 18/20 Iteration: 314300 Avg. Training loss: 0.4677 0.3491 sec/batch
# Epoch 18/20 Iteration: 314400 Avg. Training loss: 0.5082 0.3196 sec/batch
# Epoch 18/20 Iteration: 314500 Avg. Training loss: 0.4967 0.3353 sec/batch
# Epoch 18/20 Iteration: 314600 Avg. Training loss: 0.5154 0.3363 sec/batch
# Epoch 18/20 Iteration: 314700 Avg. Training loss: 0.4869 0.3281 sec/batch
# Epoch 18/20 Iteration: 314800 Avg. Training loss: 0.4933 0.3267 sec/batch
# Epoch 18/20 Iteration: 314900 Avg. Training loss: 0.5177 0.3523 sec/batch
# Epoch 18/20 Iteration: 315000 Avg. Training loss: 0.4897 0.3226 sec/batch
# Nearest to 1906: 1929, 1895, 1842, frse, 1878, 1819, schumann, 1958–59,
# Nearest to worth: $200, $2, $13, baht, $19, £, 457, proceeds,
# Nearest to category: functor, competing, weightlifter, competitive, intensity, kg, competitor, muay,
# Nearest to whilst: newcastle, nana, boscombe, margate, bath, priors, iain, busy,
# Nearest to frequency: amplitude, modulated, rfid, amplifier, polarization, relative, diffraction, deviation,
# Nearest to injury: concussion, hamstring, rookie, bone, seizures, gallen, fibula, headache,
# Nearest to register: statutes, archeological, nationality, filing, license, amendments, pawtucket, deeded,
# Nearest to little: bit, funny, considerable, UNKNOWN, crusoe, loves, spooky, cheesy,
# Nearest to shakespeares: shakespearean, hebrews, josephus, excerpts, riddles, jesper, romances, caesar,
# Nearest to irwin: gannon, rodeo, economists, heed, benton, corey, pallas, jeannie,
# Nearest to invading: forces, retreating, khanate, navies, kham, muscovy, peacekeepers, bacterium,
# Nearest to 99%: 85%, 296%, 60%, 19%, 91%, 228%, 97%, 53%,
# Nearest to protector: gwynedd, usurper, barbarian, whittingham, evangelization, overlord, nusra, bumpers,
# Nearest to reginald: eustace, watson, cbe, susie, stephens, henrietta, marjorie, recognises,
# Nearest to polished: richly, earthenware, kimi, phrasing, foreground, melancholic, [that], regalia,
# Nearest to amplitude: frequency, wave, formula_41, amplitudes, angular, formula_8, modulated, formula_34,
# Epoch 18/20 Iteration: 315100 Avg. Training loss: 0.5188 0.3219 sec/batch
# Epoch 18/20 Iteration: 315200 Avg. Training loss: 0.4716 0.3176 sec/batch
# Epoch 18/20 Iteration: 315300 Avg. Training loss: 0.5449 0.3215 sec/batch
# Epoch 18/20 Iteration: 315400 Avg. Training loss: 0.4832 0.3239 sec/batch
# Epoch 18/20 Iteration: 315500 Avg. Training loss: 0.4880 0.3405 sec/batch
# Epoch 18/20 Iteration: 315600 Avg. Training loss: 0.4783 0.3606 sec/batch
# Epoch 18/20 Iteration: 315700 Avg. Training loss: 0.5211 0.3125 sec/batch
# Epoch 18/20 Iteration: 315800 Avg. Training loss: 0.4811 0.3195 sec/batch
# Epoch 18/20 Iteration: 315900 Avg. Training loss: 0.5583 0.3143 sec/batch
# Epoch 18/20 Iteration: 316000 Avg. Training loss: 0.4640 0.3235 sec/batch
# Nearest to 1906: 1929, 1895, 1842, frse, 1878, 1819, schumann, 1958–59,
# Nearest to worth: $200, $2, $13, baht, £, $19, $3000, proceeds,
# Nearest to category: functor, competing, weightlifter, competitor, intensity, competitive, kg, muay,
# Nearest to whilst: UNKNOWN, newcastle, margate, england, boscombe, priors, duncans, oshawa,
# Nearest to frequency: amplitude, modulated, amplifier, rfid, polarization, relative, asynchronous, diffraction,
# Nearest to injury: concussion, hamstring, rookie, bone, wrist, headache, gallen, colts,
# Nearest to register: statutes, nationality, archeological, license, filing, signer, invalidated, nps,
# Nearest to little: bit, funny, UNKNOWN, crusoe, considerable, eyes, cheesy, loves,
# Nearest to shakespeares: shakespearean, josephus, hebrews, excerpts, romances, caesar, jesper, riddles,
# Nearest to irwin: gannon, rodeo, benton, economists, corey, heed, pallas, jeannie,
# Nearest to invading: forces, khanate, retreating, kham, navies, peacekeepers, mormonism, muscovy,
# Nearest to 99%: 85%, 60%, 296%, 19%, 91%, 90%, 97%, 228%,
# Nearest to protector: gwynedd, usurper, barbarian, whittingham, evangelization, overlord, nusra, bumpers,
# Nearest to reginald: watson, susie, eustace, cbe, stephens, henrietta, marjorie, baronetcy,
# Nearest to polished: richly, earthenware, phrasing, kimi, melancholic, [that], regalia, foreground,
# Nearest to amplitude: frequency, wave, formula_41, angular, amplitudes, formula_8, formula_34, modulated,
# Epoch 18/20 Iteration: 316100 Avg. Training loss: 0.4659 0.3264 sec/batch
# Epoch 18/20 Iteration: 316200 Avg. Training loss: 0.4896 0.3304 sec/batch
# Epoch 18/20 Iteration: 316300 Avg. Training loss: 0.5041 0.3292 sec/batch
# Epoch 18/20 Iteration: 316400 Avg. Training loss: 0.4602 0.3381 sec/batch
# Epoch 18/20 Iteration: 316500 Avg. Training loss: 0.5456 0.3185 sec/batch
# Epoch 18/20 Iteration: 316600 Avg. Training loss: 0.4750 0.3154 sec/batch
# Epoch 18/20 Iteration: 316700 Avg. Training loss: 0.5209 0.3211 sec/batch
# Epoch 18/20 Iteration: 316800 Avg. Training loss: 0.4891 0.3137 sec/batch
# Epoch 18/20 Iteration: 316900 Avg. Training loss: 0.4820 0.3239 sec/batch
# Epoch 18/20 Iteration: 317000 Avg. Training loss: 0.5093 0.3095 sec/batch
# Nearest to 1906: 1929, 1895, 1842, frse, 1878, schumann, 1819, 1958–59,
# Nearest to worth: $200, $2, sell, $3000, $19, $13, £, proceeds,
# Nearest to category: functor, competing, competitive, weightlifter, competitor, intensity, muay, pop/rock,
# Nearest to whilst: newcastle, UNKNOWN, iain, cassette, impressive, duncans, england, utilising,
# Nearest to frequency: amplitude, modulated, rfid, amplifier, polarization, asynchronous, relative, diffraction,
# Nearest to injury: concussion, hamstring, rookie, bone, headache, blistering, wrist, fibula,
# Nearest to register: statutes, nationality, filing, archeological, license, invalidated, allegany, creditor,
# Nearest to little: bit, UNKNOWN, funny, eyes, considerable, crusoe, cheesy, astaire,
# Nearest to shakespeares: shakespearean, josephus, excerpts, caesar, hebrews, jesper, romances, riddles,
# Nearest to irwin: gannon, rodeo, benton, economists, corey, heed, fletcher, pallas,
# Nearest to invading: forces, khanate, retreating, navies, kham, peacekeepers, muscovy, dug,
# Nearest to 99%: 85%, 296%, 91%, 19%, 60%, 97%, 228%, 53%,
# Nearest to protector: gwynedd, usurper, barbarian, whittingham, evangelization, nusra, overlord, bumpers,
# Nearest to reginald: susie, eustace, watson, cbe, stephens, henrietta, marjorie, kline,
# Nearest to polished: richly, earthenware, melancholic, phrasing, foreground, kimi, [that], cotta,
# Nearest to amplitude: frequency, wave, formula_41, amplitudes, angular, formula_34, formula_8, modulated,
# Epoch 18/20 Iteration: 317100 Avg. Training loss: 0.4518 0.3085 sec/batch
# Epoch 18/20 Iteration: 317200 Avg. Training loss: 0.5158 0.3064 sec/batch
# Epoch 18/20 Iteration: 317300 Avg. Training loss: 0.4750 0.3117 sec/batch
# Epoch 18/20 Iteration: 317400 Avg. Training loss: 0.4875 0.3182 sec/batch
# Epoch 18/20 Iteration: 317500 Avg. Training loss: 0.4849 0.3069 sec/batch
# Epoch 18/20 Iteration: 317600 Avg. Training loss: 0.4737 0.3050 sec/batch
# Epoch 18/20 Iteration: 317700 Avg. Training loss: 0.4619 0.3292 sec/batch
# Epoch 18/20 Iteration: 317800 Avg. Training loss: 0.4641 0.3071 sec/batch
# Epoch 18/20 Iteration: 317900 Avg. Training loss: 0.4718 0.3078 sec/batch
# Epoch 18/20 Iteration: 318000 Avg. Training loss: 0.4831 0.3153 sec/batch
# Nearest to 1906: 1929, 1895, 1842, 1878, frse, 1819, schumann, 1958–59,
# Nearest to worth: $200, $2, $19, $13, proceeds, sell, $3000, £,
# Nearest to category: functor, competing, competitor, weightlifter, competitive, discipline, intensity, entertainer,
# Nearest to whilst: newcastle, iain, utilising, folkestone, duncans, nana, hogwarts, impressive,
# Nearest to frequency: amplitude, rfid, modulated, amplifier, polarization, asynchronous, relative, diffraction,
# Nearest to injury: concussion, hamstring, bone, wrist, rookie, headache, gallen, colts,
# Nearest to register: statutes, nationality, license, filing, invalidated, nps, archeological, creditor,
# Nearest to little: bit, UNKNOWN, funny, eyes, considerable, 1300, crusoe, spooky,
# Nearest to shakespeares: shakespearean, josephus, excerpts, jesper, hebrews, romances, caesar, riddles,
# Nearest to irwin: gannon, benton, rodeo, economists, corey, heed, fletcher, pallas,
# Nearest to invading: forces, khanate, navies, retreating, kham, peacekeepers, attacking, muscovy,
# Nearest to 99%: 85%, 296%, 91%, 60%, 19%, 97%, 228%, 84%,
# Nearest to protector: gwynedd, usurper, barbarian, evangelization, whittingham, bumpers, overlord, nusra,
# Nearest to reginald: susie, eustace, cbe, henrietta, stephens, watson, marjorie, rawson,
# Nearest to polished: richly, earthenware, melancholic, phrasing, foreground, cotta, [that], kimi,
# Nearest to amplitude: frequency, wave, formula_41, amplitudes, angular, formula_8, formula_34, modulated,
# Epoch 18/20 Iteration: 318100 Avg. Training loss: 0.4623 0.3045 sec/batch
# Epoch 18/20 Iteration: 318200 Avg. Training loss: 0.5313 0.3023 sec/batch
# Epoch 18/20 Iteration: 318300 Avg. Training loss: 0.5275 0.3388 sec/batch
# Epoch 18/20 Iteration: 318400 Avg. Training loss: 0.5013 0.3068 sec/batch
# Epoch 18/20 Iteration: 318500 Avg. Training loss: 0.4694 0.3293 sec/batch
# Epoch 18/20 Iteration: 318600 Avg. Training loss: 0.5195 0.3058 sec/batch
# Epoch 18/20 Iteration: 318700 Avg. Training loss: 0.4973 0.3746 sec/batch
# Epoch 18/20 Iteration: 318800 Avg. Training loss: 0.4902 0.3179 sec/batch
# Epoch 18/20 Iteration: 318900 Avg. Training loss: 0.4557 0.3187 sec/batch
# Epoch 18/20 Iteration: 319000 Avg. Training loss: 0.4867 0.3033 sec/batch
# Nearest to 1906: 1929, 1895, 1842, 1878, frse, 1819, breslau, 1958–59,
# Nearest to worth: $200, $2, $19, $13, proceeds, £, $3000, sell,
# Nearest to category: functor, competing, competitive, weightlifter, discipline, competitor, intensity, muay,
# Nearest to whilst: newcastle, utilising, hogwarts, bath, iain, england, folkestone, gruff,
# Nearest to frequency: amplitude, rfid, modulated, amplifier, asynchronous, polarization, diffraction, scan,
# Nearest to injury: concussion, hamstring, bone, wrist, gallen, rookie, headache, blistering,
# Nearest to register: statutes, nationality, filing, license, nps, creditor, archeological, invalidated,
# Nearest to little: bit, funny, UNKNOWN, eyes, considerable, cheesy, crusoe, spooky,
# Nearest to shakespeares: shakespearean, josephus, excerpts, romances, jesper, hebrews, caesar, midsummer,
# Nearest to irwin: gannon, rodeo, benton, economists, fletcher, corey, heed, philadelphia,
# Nearest to invading: forces, khanate, navies, retreating, attacking, kham, peacekeepers, enemy,
# Nearest to 99%: 85%, 296%, 91%, 19%, 60%, 97%, 84%, 228%,
# Nearest to protector: usurper, gwynedd, barbarian, whittingham, evangelization, bumpers, overlord, vii,
# Nearest to reginald: susie, eustace, cbe, stephens, henrietta, marjorie, rawson, watson,
# Nearest to polished: richly, earthenware, phrasing, foreground, melancholic, kimi, regalia, [that],
# Nearest to amplitude: frequency, wave, formula_41, amplitudes, angular, formula_34, formula_8, modulated,
# Epoch 18/20 Iteration: 319100 Avg. Training loss: 0.4811 0.3039 sec/batch
# Epoch 18/20 Iteration: 319200 Avg. Training loss: 0.4719 0.3193 sec/batch
# Epoch 18/20 Iteration: 319300 Avg. Training loss: 0.5439 0.3021 sec/batch
# Epoch 18/20 Iteration: 319400 Avg. Training loss: 0.4715 0.2998 sec/batch
# Epoch 18/20 Iteration: 319500 Avg. Training loss: 0.5119 0.3082 sec/batch
# Epoch 18/20 Iteration: 319600 Avg. Training loss: 0.5083 0.3020 sec/batch
# Epoch 18/20 Iteration: 319700 Avg. Training loss: 0.5034 0.3008 sec/batch
# Epoch 18/20 Iteration: 319800 Avg. Training loss: 0.5171 0.3012 sec/batch
# Epoch 18/20 Iteration: 319900 Avg. Training loss: 0.4602 0.3071 sec/batch
# Epoch 18/20 Iteration: 320000 Avg. Training loss: 0.4965 0.3176 sec/batch
# Nearest to 1906: 1929, 1895, 1878, 1842, frse, 1819, england, 1958–59,
# Nearest to worth: $200, $2, $13, $19, proceeds, $3000, sell, £,
# Nearest to category: functor, discipline, competitive, weightlifter, competing, intensity, competitor, kg,
# Nearest to whilst: newcastle, iain, gruff, zola, utilising, margate, gannon, wardrobe,
# Nearest to frequency: amplitude, rfid, amplifier, modulated, polarization, asynchronous, variable, relative,
# Nearest to injury: concussion, hamstring, bone, wrist, rookie, colts, gallen, headache,
# Nearest to register: statutes, filing, nps, license, nationality, abbie, greenway, creditor,
# Nearest to little: bit, UNKNOWN, funny, considerable, cheesy, eyes, crusoe, wiser,
# Nearest to shakespeares: shakespearean, josephus, excerpts, romances, hebrews, caesar, jesper, riddles,
# Nearest to irwin: gannon, rodeo, philadelphia, benton, corey, heed, fletcher, coutts,
# Nearest to invading: forces, khanate, navies, attacking, retreating, kham, ottoman, peacekeepers,
# Nearest to 99%: 85%, 296%, 91%, 19%, 60%, 97%, 228%, 84%,
# Nearest to protector: usurper, gwynedd, barbarian, whittingham, evangelization, bumpers, overlord, vii,
# Nearest to reginald: susie, eustace, cbe, henrietta, stephens, rawson, kline, marjorie,
# Nearest to polished: richly, foreground, earthenware, phrasing, melancholic, regalia, kimi, [that],
# Nearest to amplitude: frequency, wave, formula_41, amplitudes, angular, formula_34, formula_8, variable,
# Epoch 18/20 Iteration: 320100 Avg. Training loss: 0.4709 0.3239 sec/batch
# Epoch 18/20 Iteration: 320200 Avg. Training loss: 0.4906 0.3128 sec/batch
# Epoch 18/20 Iteration: 320300 Avg. Training loss: 0.4831 0.3009 sec/batch
# Epoch 18/20 Iteration: 320400 Avg. Training loss: 0.4618 0.3044 sec/batch
# Epoch 18/20 Iteration: 320500 Avg. Training loss: 0.5313 0.3013 sec/batch
# Epoch 18/20 Iteration: 320600 Avg. Training loss: 0.5039 0.2975 sec/batch
# Epoch 18/20 Iteration: 320700 Avg. Training loss: 0.4814 0.2988 sec/batch
# Epoch 18/20 Iteration: 320800 Avg. Training loss: 0.4904 0.3157 sec/batch
# Epoch 18/20 Iteration: 320900 Avg. Training loss: 0.5136 0.2961 sec/batch
# Epoch 18/20 Iteration: 321000 Avg. Training loss: 0.4723 0.3005 sec/batch
# Nearest to 1906: 1929, 1895, 1878, 1842, frse, 1819, england, 1958–59,
# Nearest to worth: $2, $200, $13, proceeds, sell, $3000, $19, $18,
# Nearest to category: functor, competitive, discipline, weightlifter, competing, intensity, competitor, kg,
# Nearest to whilst: UNKNOWN, newcastle, iain, utilising, england, folkestone, margate, suicidal,
# Nearest to frequency: amplitude, rfid, amplifier, modulated, polarization, asynchronous, scan, diffraction,
# Nearest to injury: concussion, hamstring, bone, cornerback, wrist, rookie, colts, headache,
# Nearest to register: statutes, filing, license, nps, abbie, deeded, nationality, creditor,
# Nearest to little: bit, UNKNOWN, considerable, eyes, funny, astaire, eccentric, seeing,
# Nearest to shakespeares: shakespearean, excerpts, josephus, romances, riddles, hebrews, caesar, jesper,
# Nearest to irwin: gannon, rodeo, philadelphia, benton, corey, heed, economists, fletcher,
# Nearest to invading: forces, khanate, navies, attacking, kham, retreating, repelling, ottoman,
# Nearest to 99%: 85%, 296%, 91%, 60%, 19%, 225%, 84%, 228%,
# Nearest to protector: usurper, gwynedd, barbarian, whittingham, evangelization, bumpers, nusra, overlord,
# Nearest to reginald: susie, eustace, cbe, henrietta, stephens, kline, marjorie, rawson,
# Nearest to polished: richly, phrasing, kimi, melancholic, foreground, regalia, earthenware, [that],
# Nearest to amplitude: frequency, wave, formula_41, amplitudes, angular, formula_8, formula_34, modulated,
# Epoch 18/20 Iteration: 321100 Avg. Training loss: 0.5009 0.3047 sec/batch
# Epoch 18/20 Iteration: 321200 Avg. Training loss: 0.4967 0.3184 sec/batch
# Epoch 18/20 Iteration: 321300 Avg. Training loss: 0.4431 0.2995 sec/batch
# Epoch 18/20 Iteration: 321400 Avg. Training loss: 0.5107 0.3062 sec/batch

# %% [markdown]
# # Restoring to the last checkpoint

# %%
with train_graph.as_default():
    saver = tf.train.Saver()

with tf.Session(graph=train_graph) as sess:
    saver.restore(sess, tf.train.latest_checkpoint('checkpoints'))
    embed_mat = sess.run(embedding)

# %% [markdown]
# ## Visualizing the word vectors
#
# T-SNE is used to project these vectors into two dimensions while preserving local stucture.

# %%
# %matplotlib inline
# %config InlineBackend.figure_format = 'retina'

import matplotlib.pyplot as plt
from sklearn.manifold import TSNE

# %%
viz_words = 500
tsne = TSNE()
embed_tsne = tsne.fit_transform(embed_mat[:viz_words, :])

# %%
fig, ax = plt.subplots(figsize=(14, 14))
for idx in range(viz_words):
    plt.scatter(*embed_tsne[idx, :], color='steelblue')
    plt.annotate(idx2word_sampled[idx], (embed_tsne[idx, 0], embed_tsne[idx, 1]), alpha=0.7)

# %% [markdown]
# # The tensorflow projector

# %%
import os
with open(os.path.join('checkpoints', "metadata.tsv"), 'w') as f:
     for idx in range(len(idx2word_sampled)):
        f.write(idx2word_sampled[idx] + '\n')

# %%
from tensorflow.contrib.tensorboard.plugins import projector

summary_writer = tf.summary.FileWriter('checkpoints', sess.graph)
config = projector.ProjectorConfig()
embedding_conf = config.embeddings.add()
# embedding_conf.tensor_name = 'embedding:0'
embedding_conf.metadata_path = os.path.join('checkpoints', 'metadata.tsv')
projector.visualize_embeddings(summary_writer, config)

# %%
embedding_conf.metadata_path
